# %%
# %%time
import sys, os
path_dir = os.getcwd()
sys.path.append(path_dir+"/Functions")
from General_functions import *
from Input_func import *
from IO_Plots import *
from PC_Plots import *
from DCN_Plots import *
from read_data import *
from New_func import *
start_scope()
###################################################################
######################### Load Parameters #########################
###################################################################
Name_BCM = "Learned_BCM"
time_now_BCM = "09:15"
Name_No_BCM = "No_BCM"
time_now_No_BCM = "09:47"
date = "06-07"
Frozen_data = sio.loadmat('Data/'+date+'/Frozen.mat', squeeze_me=True)
Params, Noise_frozen, Values, Synapses = Read_Input(Frozen_data)
###################################################################
############################ Load Data ############################
###################################################################
Output_Noise_No_BCM, Output_Noise_Extended_No_BCM, Output_PC_No_BCM, Output_DCN_No_BCM, Output_IO_No_BCM, Output_mon_N_PC_No_BCM, Output_Noise_Coupled_No_BCM, Output_Noise_Extended_Coupled_No_BCM, Output_PC_Coupled_No_BCM, Output_DCN_Coupled_No_BCM, Output_IO_Coupled_No_BCM, Output_mon_N_PC_Coupled = load_data(Name_No_BCM, time_now_No_BCM, date)
Output_Noise_BCM, Output_Noise_Extended_BCM, Output_PC_BCM, Output_DCN_BCM, Output_IO_BCM, Output_mon_N_PC_BCM, Output_Noise_Coupled_BCM, Output_Noise_Extended_Coupled_BCM, Output_PC_Coupled_BCM, Output_DCN_Coupled_BCM, Output_IO_Coupled_BCM, Output_mon_N_PC_Coupled = load_data(Name_BCM, time_now_BCM, date)
###################################################################
########################### Load Cells ############################
###################################################################
Noise, Noise_Extended, PC, DCN, IO, mon_N_PC = Output_func(Name_BCM,"",Output_Noise_BCM, Output_Noise_Extended_BCM, Output_PC_BCM, Output_DCN_BCM, Output_IO_BCM, Output_mon_N_PC_BCM, Output_Noise_Coupled_BCM, Output_Noise_Extended_Coupled_BCM, Output_PC_Coupled_BCM, Output_DCN_Coupled_BCM, Output_IO_Coupled_BCM, Output_mon_N_PC_Coupled)
Noise_Coupled, Noise_Extended_Coupled, PC_Coupled, DCN_Coupled, IO_Coupled, mon_N_PC_Coupled = Output_func(Name_BCM,"Coupled",Output_Noise_BCM, Output_Noise_Extended_BCM, Output_PC_BCM, Output_DCN_BCM, Output_IO_BCM, Output_mon_N_PC_BCM, Output_Noise_Coupled_BCM, Output_Noise_Extended_Coupled_BCM, Output_PC_Coupled_BCM, Output_DCN_Coupled_BCM, Output_IO_Coupled_BCM, Output_mon_N_PC_Coupled)
time_x = Noise.t


Noise_BCM_BCM, Noise_Extended_BCM_BCM, PC_BCM, DCN_BCM, IO_BCM, mon_N_PC_BCM = Output_func(Name_BCM,"",Output_Noise_BCM, Output_Noise_Extended_BCM, Output_PC_BCM, Output_DCN_BCM, Output_IO_BCM, Output_mon_N_PC_BCM, Output_Noise_Coupled_BCM, Output_Noise_Extended_Coupled_BCM, Output_PC_Coupled_BCM, Output_DCN_Coupled_BCM, Output_IO_Coupled_BCM, Output_mon_N_PC_Coupled)
Noise_Coupled_BCM, Noise_Extended_Coupled_BCM, PC_Coupled_BCM, DCN_Coupled_BCM, IO_Coupled_BCM, mon_N_PC_Coupled_BCM = Output_func(Name_BCM,"Coupled",Output_Noise_BCM, Output_Noise_Extended_BCM, Output_PC_BCM, Output_DCN_BCM, Output_IO_BCM, Output_mon_N_PC_BCM, Output_Noise_Coupled_BCM, Output_Noise_Extended_Coupled_BCM, Output_PC_Coupled_BCM, Output_DCN_Coupled_BCM, Output_IO_Coupled_BCM, Output_mon_N_PC_Coupled)
time_x = Noise.t




Name_data = ""

step = 600
step = int(step/(Params.dt_rec/msecond))
xx = range(-step,step)
xx1 = [item * (Params.dt_rec/msecond) for item in xx]
# Out:
# CPU times: user 2.45 s, sys: 2.78 s, total: 5.23 s
# Wall time: 6.98 s

# %%
# PC_new = New_PC(Params,PC)
# PC_new_Coupled = New_PC(Params,PC_Coupled)
# PC_new_learned = New_PC_learned(Params,PC_BCM)
# PC_new_learned_Coupled = New_PC_learned(Params,PC_BCM)

# IO_CS, IO_Size, cc, avrg_CS, avrg_CS_all = CS_plots(step,"",Params,Synapses,IO)
# IO_CS_Coupled, IO_Size_Coupled, cc_Coupled, avrg_CS_Coupled, avrg_CS_all_Coupled = CS_plots(step,"",Params,Synapses,IO_Coupled)

# IO_CS_learned, IO_Size_learned, cc, avrg_CS_learned, avrg_CS_all_learned = CS_plots(step,"Learned",Params,Synapses,IO)
# IO_CS_learned_Coupled, IO_Size_learned_Coupled, cc_learned_Coupled, avrg_CS_learned_Coupled, avrg_CS_all_learned_Coupled = CS_plots(step,"Learned",Params,Synapses,IO_Coupled)

# PC_CS, cc_PC, avrg_PC, avrg_PC_all = CS_PC(step,"",Params,Synapses,PC_new,IO)
# PC_CS_Coupled, cc_PC_Coupled, avrg_PC_Coupled, avrg_PC_all_Coupled = CS_PC(step,"",Params,Synapses,PC_new_Coupled,IO_Coupled)

# PC_CS_learned, cc_PC_learned, avrg_PC_learned, avrg_PC_all_learned = CS_PC(step,"Learned",Params,Synapses,PC_new,IO)
# PC_CS_learned_Coupled, cc_PC_learned_Coupled, avrg_PC_learned_Coupled, avrg_PC_all_learned_Coupled = CS_PC(step,"Learned",Params,Synapses,PC_new_Coupled,IO_Coupled)

# %%
# learned = "Learned"
# kk = 0
# aa = [[]]*size(Synapses.IO_PC_Synapse_Sources)
# bb = [[]]*size(Synapses.IO_PC_Synapse_Sources)
# cc = [[]]*size(Synapses.IO_PC_Synapse_Sources)
# IO_CS = [[]]*size(Synapses.IO_PC_Synapse_Sources)
# IO_Size = [[]]*len(IO_CS)
# for ii in Synapses.IO_PC_Synapse_Sources:
#     if learned == "Learned":
#         IO_spikes = IO.Spikemon_Cells[ii][len(IO.Spikemon_Cells[ii])//2:]
#     else: 
#         IO_spikes = IO.Spikemon_Cells[ii][:len(IO.Spikemon_Cells[ii])//2]
#     IO_CS[kk] = [[]]*size(IO_spikes)
#     for jj in range(0,size(IO_spikes)):
#         spike = IO_spikes[jj]/(Params.dt_rec/second)
#         IO_CS[kk][jj] = (IO.Vs[ii][int(spike-step):int(spike+step)]/mV)
#     kk += 1


# for ii in range(0,len(IO_CS)):
#     IO_Size[ii] = [[]]*len(IO_CS[ii])
#     for jj in range(0,len(IO_CS[ii])):
#         IO_Size[ii][jj] = len(IO_CS[ii][jj]) 

# kk = 0
# for ii in Synapses.IO_PC_Synapse_Sources:
#     if learned == "Learned":
#         IO_spikes = IO.Spikemon_Cells[ii][len(IO.Spikemon_Cells[ii])//2:]
#     else: 
#         IO_spikes = IO.Spikemon_Cells[ii][:len(IO.Spikemon_Cells[ii])//2]
#     aa[kk] = [[]]*size(IO_spikes)
#     bb[kk] = [[]]*size(IO_spikes)
#     for jj in range(0,size(IO_spikes)):
#         spike = IO_spikes[jj]/(Params.dt_rec/second)
#         aa[kk][jj] = IO.Vs[ii][int(spike-step):int(spike+step)]
#         if size(aa[kk][jj]) != most_frequent(IO_Size[kk]):
#             continue
#         bb[kk][jj] = IO.Vs[ii][int(spike-step):int(spike+step)]
#     cc[kk] = [x for x in bb[kk] if x != []]    
#     kk+=1

# avrg_CS = [[]]*len(cc)
# for ii in range(0,len(cc)):
#     avrg_CS[ii] = np.mean(cc[ii], axis=0)

# avrg_CS_all = np.mean(avrg_CS, axis=0)

# %%
start1 = int(5/(Params.dt_rec/second))
end1 = int(15/(Params.dt_rec/second))
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_DCN):
    plot(time_x[start1:end1],IO.Vs[ii][start1:end1]/mV, label='IO_'+str(ii+1))
title('Membrane Potential for '+str(Params.N_Cells_IO)+" cells")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    vm = PC.v[ii]
    for t in PC.Spikemon_Cells[ii]:
        i = int(t / Params.dt_rec)
        vm[i] = 20*mV
    plot(time_x[start1:end1],vm[start1:end1]/mV, label='PC_'+str(ii+1))
title('Membrane Potential for '+str(Params.N_Cells_PC)+" cells")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    plot(time_x[start1:end1],PC.I_Noise[ii][start1:end1]/nA, label='PSC_PC_'+str(ii+1))
title('PSC for '+str(Params.N_Cells_PC)+" cells")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Noise):
    plot(time_x[start1:end1],Noise.I[ii][start1:end1]/nA, label='Noise_Input_'+str(ii+1))
title('Current for '+str(Params.N_Noise)+" cells")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    vm = PC.v[ii]
    for t in PC.Spikemon_Cells[ii]:
        i = int(t / Params.dt_rec)
        vm[i] = 20*mV
    plot(time_x/ms,vm/mV, label='PC_'+str(ii+1))
title('Membrane Potential for '+str(Params.N_Cells_PC)+" cells")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_DCN):
    plot(time_x/ms,DCN.v[ii]/mV, label='DCN_'+str(ii+1))
title('Membrane Potential for '+str(Params.N_Cells_DCN)+" cells")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_DCN):
    plot(time_x/ms,IO.Vs[ii]/mV, label='IO_'+str(ii+1))
title('Membrane Potential for '+str(Params.N_Cells_IO)+" cells")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    vm = PC_Coupled.v[ii]
    for t in PC_Coupled.Spikemon_Cells[ii]:
        i = int(t / Params.dt_rec)
        vm[i] = 20*mV
    plot(time_x/ms,vm/mV, label='PC_'+str(ii+1))
title('Membrane Potential for '+str(Params.N_Cells_PC)+" cells")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_DCN):
    plot(time_x/ms,DCN_Coupled.v[ii]/mV, label='DCN_'+str(ii+1))
title('Membrane Potential for '+str(Params.N_Cells_DCN)+" cells")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_DCN):
    plot(time_x/ms,IO_Coupled.Vs[ii]/mV, label='IO_'+str(ii+1))
title('Membrane Potential for '+str(Params.N_Cells_IO)+" cells")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

# %%
for ii in range(0,Params.N_Cells_IO):
    plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
    plot(time_x,IO.Vs[ii]/mV, label='IO'+str(ii+1))
    plot(time_x,IO_Coupled.Vs[ii]/mV, label='IO_Coupled'+str(ii+1))
    title('Membrane Potential for '+str(Params.N_Cells_IO)+" cells")
    ylabel('V [mV]')
    xlabel('Time [ms]')
    legend()
    show()

# %%
for ii in range(0,Params.N_Cells_PC):
    plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
    plot(time_x,PC.w[ii]/nA, label='PC_'+str(ii+1))
    plot(time_x,PC_Coupled.w[ii]/nA, label='PC_Coupled_'+str(ii+1))
    title('Adaptive parameter w for '+str(Params.N_Cells_PC)+" cells")
    ylabel('w [nA]')
    xlabel('Time [ms]')
    legend()
    show()

# %%
if Name_data != "STDP":
    plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
    plot(time_x,mon_N_PC.rho_PF[0])
    ylabel('rho_PF [Hz]')
    xlabel('Time [ms]')
    show()

    plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
    for ii in range(0,Params.N_Cells_PC):
        plot(time_x,mon_N_PC.rho_PC[ii])
    ylabel('rho_PC [Hz]')
    xlabel('Time [ms]')
    show()

# %%
if Name_data != "STDP":
    plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
    for ii in range(0,Params.N_Cells_PC*Params.N_Noise):
        plot(mon_N_PC.rho_PC[0],mon_N_PC.phi[ii])
    ylabel('phi [Hz]')
    xlabel('rho_PC [Hz]')
    show()

    plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
    for ii in range(0,Params.N_Cells_PC*Params.N_Noise):
        plot(time_x,mon_N_PC.thresh_M[ii])
    ylabel('thresh_M [Hz]')
    xlabel('Time [ms]')
    show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC*Params.N_Noise):
    plot(time_x,mon_N_PC.delta_weight[ii], label='PC_'+str(ii+1))
ylabel('delta_weight [-]')
xlabel('Time [ms]')
legend()
show()

if Name_data != "STDP":
    plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
    for ii in range(0,Params.N_Cells_PC*Params.N_Noise):
        plot(time_x,mon_N_PC.new_weight[ii], label='PC_'+str(ii+1))
    ylabel('new_weight [-]')
    xlabel('Time [ms]')
    legend()
    show()
# Out:
# WARNING    /Users/eliasmateofernandezsantoro/Python/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
#  [py.warnings]
# WARNING:py.warnings:/Users/eliasmateofernandezsantoro/Python/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING    /Users/eliasmateofernandezsantoro/Python/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
#  [py.warnings]
# ...

# %%
for ii in range(0,Params.N_Cells_PC):
    plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
    plot(time_x,PC.recent_rate[ii]/Hz, label='recent_rate_PSC_Cell'+str(ii+1))
    plot(time_x,PC.New_recent_rate[ii]/Hz, label='New_recent_rate_PSC_Cell'+str(ii+1))
    ylabel('PC recent rate [Hz]')
    xlabel('Time [ms]')
    legend()
    show()

# %%
for ii in range(0,Params.N_Cells_PC):
    plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
    plot(time_x,PC_Coupled.recent_rate[ii]/Hz, label='recent_rate_PSC_Cell'+str(ii+1))
    plot(time_x,PC_Coupled.New_recent_rate[ii]/Hz, label='New_recent_rate_PSC_Cell'+str(ii+1))
    ylabel('PC recent rate [Hz]')
    xlabel('Time [ms]')
    legend()
    show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    plot(time_x,PC.recent_rate[ii]/Hz, label='PSC_Cell'+str(ii+1))
ylabel('PC recent rate [Hz]')
xlabel('Time [ms]')
legend()
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    plot(time_x,PC.New_recent_rate[ii]/Hz, label='PSC_Cell'+str(ii+1))
ylabel('PC recent rate [Hz]')
xlabel('Time [ms]')
legend()
show()


plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    plot(time_x,PC_Coupled.recent_rate[ii]/Hz, label='PSC_Cell'+str(ii+1))
ylabel('PC recent rate [Hz]')
xlabel('Time [ms]')
legend()
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    plot(time_x,PC_Coupled.New_recent_rate[ii]/Hz, label='PSC_Cell'+str(ii+1))
ylabel('PC recent rate [Hz]')
xlabel('Time [ms]')
legend()
show()

# %%
# plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
# for ii in range(0,Params.N_Cells_PC):
#     vm = PC.v[:]
#     for t in PC.Spikemon:
#         i = int(t / Params.dt_rec)
#         vm[i] = 20*mV
#     plot(PC_Statemon.t/ms,vm/mV, label='PC_'+str(ii+1))
# title('Membrane Potential for '+str(Params.N_Cells_PC)+" cells")
# ylabel('V [mV]')
# xlabel('Time [ms]')
# legend()
# show()

# plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
# for ii in range(0,Params.N_Cells_PC):
#     vm_Coupled = PC_Statemon_Coupled[ii].v[:]
#     for t in PC_Spikemon_Coupled.t:
#         i = int(t / dt_rec)
#         vm_Coupled[i] = 20*mV
#     plot(PC_Statemon_Coupled.t/ms,vm_Coupled/mV, label='PC_'+str(ii+1))
# title('Membrane Potential for '+str(Params.N_Cells_PC)+" cells")
# ylabel('V [mV]')
# xlabel('Time [ms]')
# legend()
# show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    plot(time_x,PC.I_Noise[ii]/nA, label='PSC_Cell'+str(ii+1))
#     plot(Noise_statemon.t/ms,Noise_statemon.I[ii]/nA, label='Noise'+str(ii+1))
title('Post synaptic current for '+str(Params.N_Cells_PC)+" cells and "+str(Params.N_Noise)+" sources")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    plot(time_x,PC_Coupled.I_Noise[ii]/nA, label='PSC_Cell'+str(ii+1))
#     plot(Noise_statemon.t/ms,Noise_statemon.I[ii]/nA, label='Noise'+str(ii+1))
title('Post synaptic current for '+str(Params.N_Cells_PC)+" cells and "+str(Params.N_Noise)+" sources (Coupled)")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

# %%
IO_plot_neurons(Params.N_Cells_IO,IO,time_x,"Uncoupled") #Membrane potential for the uncoupled scenario (0% strength)
IO_plot_neurons(Params.N_Cells_IO,IO_Coupled,time_x,"Coupled")

# %%
PC_pop_rate_plot(Params.N_Cells_PC,'gaussian',100*ms,PC.rate_time,PC.rate,PC_Coupled.rate)

# %%
DCN_pop_rate_plot(Params.N_Cells_DCN,'gaussian',100*ms,PC.rate_time,DCN.rate,DCN_Coupled.rate)

# %%
IO_pop_rate_plot(Params.N_Cells_IO,'gaussian',100*ms,PC.rate_time,IO.rate,IO_Coupled.rate)

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC):
    plot(time_x,PC.I_Noise[ii]/nA, label='PSC_Cell'+str(ii+1))
    plot(time_x,PC.I_Noise_empty[ii]/nA, label='Noise on Cell'+str(ii+1))
title('Post synaptic current for '+str(Params.N_Cells_PC)+" cells and "+str(Params.N_Noise)+" sources")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()
# Out:
# WARNING    /Users/eliasmateofernandezsantoro/Python/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
#  [py.warnings]
# WARNING:py.warnings:/Users/eliasmateofernandezsantoro/Python/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Noise):
    plot(time_x,Noise.I[ii]/nA, label='Noise'+str(ii+1))
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

# %%
### plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Noise):
    plot(time_x,Noise_Extended.I[ii]/nA, label='Noise'+str(ii+1))
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()
# Out:
# WARNING    /Users/eliasmateofernandezsantoro/Python/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
#  [py.warnings]
# WARNING:py.warnings:/Users/eliasmateofernandezsantoro/Python/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
