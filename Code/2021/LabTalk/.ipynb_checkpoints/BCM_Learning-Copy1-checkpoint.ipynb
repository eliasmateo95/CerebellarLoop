# %%
# %%time
import sys, os
path_dir = os.getcwd()
sys.path.append(path_dir+"/Functions")
from Noise_functions import *
from PC_functions import *
from DCN_functions import *
from IO_functions import *
from Noise_PC_Synapses_functions import *
from PC_DCN_Synapses_functions import *
from DCN_IO_Synapses_functions import *
from IO_PC_Synapses_functions import *
from Other_synapses import *
from IO_Plots import *
from PC_Plots import *
from DCN_Plots import *
from Input_func import *
start_scope()
###################################################################
######################### Load Parameters #########################
###################################################################
Frozen_data = sio.loadmat('Data/'+datetime.datetime.now().strftime("%m-%d")+'/Frozen.mat', squeeze_me=True)
Params, Noise_frozen, Values, Synaps = Read_Input(Frozen_data)
###################################################################
######################## Initial Parameters #######################
###################################################################
dt = Params.dt
dt_rec = Params.dt_rec
width = Params.width
tau_noise = Params.tau_noise
exp_run = Params.exp_run
N_Noise = Params.N_Noise
N_Cells_PC = Params.N_Cells_PC
N_Cells_DCN = Params.N_Cells_DCN
N_Cells_IO = Params.N_Cells_IO
N_Copy = Params.N_Copy
N_Copy_order = Params.N_Copy_order
###################################################################
########################## Cell Values ############################
###################################################################
Noise_I = Noise_frozen.Noise_I
I_recorded = Noise_frozen.I_recorded
period = Noise_frozen.period
PC_Values = Values.PC_Values
DCN_Values = Values.DCN_Values
IO_Values = Values.IO_Values
IO_thresh = Values.IO_thresh
eqs_IO_syn = Values.eqs_IO_syn
rate_meas = Values.rate_meas
rate_meas_out = Values.rate_meas_out
tau_presyn = Values.tau_presyn
tau_thresh_M = 10*ms# Values.tau_thresh_M
sine_amplitude_presyn = Values.sine_amplitude_presyn
sine_frequency_presyn = Values.sine_frequency_presyn
eqs_syn_bcm_s_n_pc = Values.eqs_syn_bcm_s_n_pc
eqs_syn_IO_PC_pre = Values.eqs_syn_IO_PC_pre
###################################################################
###################### Synapses Values ############################
###################################################################
IO_Copy_Synapse_Targets = Synaps.IO_Copy_Synapse_Targets
Noise_PC_Synapse_Sources = Synaps.Noise_PC_Synapse_Sources
Noise_PC_Synapse_Targets = Synaps.Noise_PC_Synapse_Targets 
Noise_PC_Synapse_Weights = Synaps.Noise_PC_Synapse_Weights
PC_DCN_Synapse_Sources = Synaps.PC_DCN_Synapse_Sources
PC_DCN_Synapse_Targets = Synaps.PC_DCN_Synapse_Targets
DCN_IO_Synapse_Sources = Synaps.DCN_IO_Synapse_Sources 
DCN_IO_Synapse_Targets = Synaps.DCN_IO_Synapse_Targets 
IO_PC_Synapse_Sources = Synaps.IO_PC_Synapse_Sources
IO_PC_Synapse_Targets = Synaps.IO_PC_Synapse_Targets


def presyn_inp(N_Noise,sine_amplitude_presyn,sine_frequency_presyn, dt, dt_rec):
    eqs_presyn = '''
            rho_presyn = ampli*noise_in: Hz
            noise_in : 1
            ampli : Hz
            '''
    Input_presyn = NeuronGroup(N_Noise, eqs_presyn, threshold='True', method='euler', dt=dt)
    Input_presyn_statemon = StateMonitor(Input_presyn, variables=['rho_presyn'], record=True, dt=dt_rec)
    ampli = rand_params(30,Hz,N_Noise,(5/N_Noise))
    for ii in range(0, N_Noise, 1):
        Input_presyn.ampli[ii] = ampli[ii]
    return Input_presyn, Input_presyn_statemon
###################################################################
###################################################################
############################## CELLS ##############################
###################################################################
###################################################################
############################## NOISE ##############################
###################################################################
Noise, Noise_statemon, Noise_extended, Noise_extended_statemon = Noise_neuron(N_Noise,I_recorded,period,dt,dt_rec)
###################################################################
########################## PURKINJE CELL ##########################
###################################################################
PC, PC_Statemon, PC_Spikemon, PC_rate = PC_neurons(N_Cells_PC,PC_Values,dt,dt_rec)
###################################################################
################## DEEP CEREBELLAR NUCLEI CELLS ###################
###################################################################
DCN, DCN_Statemon, DCN_Spikemon, DCN_rate = DCN_neurons(N_Cells_DCN,DCN_Values,dt,dt_rec)
###################################################################
############################# IO ##################################
###################################################################
IO, IO_Statemon, IO_Spikemon, IO_rate = IO_neurons(N_Cells_IO,IO_Values,IO_thresh,dt,dt_rec)
###################################################################
############################# PF ##################################
###################################################################
Input_presyn, Input_presyn_statemon = presyn_inp(N_Noise,sine_amplitude_presyn,sine_frequency_presyn, dt, dt_rec)
###################################################################
############################# Rate ################################
###################################################################
syn = rate_meas_func(rate_meas,PC,dt)
syn.connect(j='i')  
syn.subtract.delay = rate_meas_out  # delay the subtraction
###################################################################
############################# Copy ################################
###################################################################
conn_N_PC, mon_N_PC = conn_N_PC_func(N_Copy, Noise_PC_Synapse_Weights, dt, dt_rec)
###################################################################
###################################################################
########################## SYNAPSES ###############################
###################################################################
###################################################################
########################## PC DCN Synapse #########################
###################################################################
PC_DCN_Synapse = PC_DCN_syn(PC,DCN,N_Cells_PC,N_Cells_DCN,dt,dt_rec)
PC_DCN_Synapse.connect(i=PC_DCN_Synapse_Sources,j=PC_DCN_Synapse_Targets)
###################################################################
########################## DCN IO Synapse #########################
###################################################################
DCN_IO_Synapse = DCN_IO_syn(DCN,IO,N_Cells_DCN,N_Cells_IO,dt,dt_rec)
DCN_IO_Synapse.connect(i=DCN_IO_Synapse_Sources,j=DCN_IO_Synapse_Targets)
###################################################################
########################## IO ConnPC Synapse ######################
###################################################################
S_IO_N = Synapses(IO, conn_N_PC, method='euler',dt=dt)  # where f is 
S_IO_N.connect(i=IO_PC_Synapse_Sources, j=IO_Copy_Synapse_Targets)
###################################################################
########################### IO PC Synapse #########################
###################################################################
IO_PC_Synapse = Synapses(IO, PC, on_pre =eqs_syn_IO_PC_pre, delay=2*ms,method = 'euler',dt=dt)
IO_PC_Synapse.connect(i=IO_PC_Synapse_Sources,j=IO_PC_Synapse_Targets)
###################################################################
######################### ConnPC PC Synapse #######################
###################################################################
S_N_PC = Synapses(conn_N_PC,PC, eqs_syn_bcm_s_n_pc, method='euler',dt=dt)
S_N_PC.connect(i=N_Copy_order, j = Noise_PC_Synapse_Targets)
###################################################################
########################## ConnPC Noise Synapse ###################
###################################################################
S_PC_N = Synapses(conn_N_PC,Noise_extended, 'weight_post = new_weight_pre : 1 (summed)', method='euler',dt=dt)
S_PC_N.connect(i=N_Copy_order, j = Noise_PC_Synapse_Sources)
###################################################################
############################# Copy rate ###########################
###################################################################
copy_rate = Synapses(Input_presyn, conn_N_PC, 'rho_PF_post = rho_presyn_pre : Hz (summed)', method='euler',dt=dt)
copy_rate.connect(i = Noise_PC_Synapse_Sources, j=N_Copy_order)
###################################################################
############################ Copy Noise ###########################
###################################################################
copy_noise = Synapses(Noise_extended, conn_N_PC, 'I_post = I_pre : amp (summed)', method='euler', dt=dt)
copy_noise.connect(i = Noise_PC_Synapse_Sources, j=N_Copy_order)
copy_noise.weight = Noise_PC_Synapse_Weights
###################################################################
########################## PC Rate Synapse ########################
###################################################################
S_PC_rate = Synapses(PC,conn_N_PC, 'rho_PC_post = New_recent_rate_pre : Hz (summed)', method='euler',dt=dt)
S_PC_rate.connect(i=Noise_PC_Synapse_Targets, j =N_Copy_order)

presyn_Noise_syn = Synapses(Noise_extended, Input_presyn, 'noise_in_post = I_pre/nA : 1 (summed)',method='euler',dt=dt)  # where f is 
presyn_Noise_syn.connect(j = 'i')
# Out:
# ld: warning: -pie being ignored. It is only used when linking a main executable
# ld: unsupported tapi file type '!tapi-tbd' in YAML file '/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/lib/libSystem.tbd' for architecture x86_64
# clang-10: error: linker command failed with exit code 1 (use -v to see invocation)
# WARNING    Cannot use Cython, a test compilation failed: command 'x86_64-apple-darwin13.4.0-clang++' failed with exit status 1 (LinkError) [brian2.codegen.runtime.cython_rt.cython_rt.failed_compile_test]
# INFO       Cannot use compiled code, falling back to the numpy code generation target. Note that this will likely be slower than using compiled code. Set the code generation to numpy manually to avoid this message:
# prefs.codegen.target = "numpy" [brian2.devices.device.codegen_fallback]
# CPU times: user 2.38 s, sys: 572 ms, total: 2.95 s
# Wall time: 5.28 s

# %%
###################################################################
###################################################################
############################## CELLS COUPLED ######################
###################################################################
###################################################################
############################## NOISE COUPLED ######################
###################################################################
Noise_Coupled, Noise_statemon_Coupled, Noise_extended_Coupled, Noise_extended_statemon_Coupled = Noise_neuron(N_Noise,I_recorded,period,dt,dt_rec)
###################################################################
########################## PURKINJE CELL COUPLED ##################
###################################################################
PC_Coupled, PC_Statemon_Coupled, PC_Spikemon_Coupled, PC_rate_Coupled = PC_neurons(N_Cells_PC,PC_Values,dt,dt_rec)
###################################################################
################ DEEP CEREBELLAR NUCLEI CELLS COUPLED #############
###################################################################
DCN_Coupled, DCN_Statemon_Coupled, DCN_Spikemon_Coupled, DCN_rate_Coupled = DCN_neurons(N_Cells_DCN,DCN_Values,dt,dt_rec)
###################################################################
############################# IO COUPLED ##########################
###################################################################
IO_Coupled, IO_Statemon_Coupled, IO_Spikemon_Coupled, IO_rate_Coupled = IO_neurons(N_Cells_IO,IO_Values,IO_thresh,dt,dt_rec)
IO_synapse_Coupled = IO_coup_syn(IO_Coupled,eqs_IO_syn) # create synaptic equations and apply full synaptic strength for second network
IO_synapse_Coupled.connect() # connect second network
###################################################################
############################# PF COUPLED ##########################
###################################################################
Input_presyn_Coupled, Input_presyn_statemon_Coupled = presyn_inp(N_Noise,sine_amplitude_presyn,sine_frequency_presyn, dt, dt_rec)
###################################################################
############################# Rate COUPLED ########################
###################################################################
syn_Coupled = rate_meas_func(rate_meas,PC_Coupled,dt)
syn_Coupled.connect(j='i')  
syn_Coupled.subtract.delay = rate_meas_out  # delay the subtraction 
###################################################################
############################# Copy COUPLED ########################
###################################################################
conn_N_PC_Coupled, mon_N_PC_Coupled = conn_N_PC_func(N_Copy, Noise_PC_Synapse_Weights, dt, dt_rec)
###################################################################
###################################################################
####################### SYNAPSES COUPLED ##########################
###################################################################
###################################################################
########################## PC DCN Synapse #########################
###################################################################
PC_DCN_Synapse_Coupled = PC_DCN_syn(PC_Coupled,DCN_Coupled,N_Cells_PC,N_Cells_DCN,dt,dt_rec)
PC_DCN_Synapse_Coupled.connect(i=PC_DCN_Synapse_Sources,j=PC_DCN_Synapse_Targets)
###################################################################
#################### DCN IO Synapse COUPLED #######################
###################################################################
DCN_IO_Synapse_Coupled = DCN_IO_syn(DCN_Coupled,IO_Coupled,N_Cells_DCN,N_Cells_IO,dt,dt_rec)
DCN_IO_Synapse_Coupled.connect(i=DCN_IO_Synapse_Sources,j=DCN_IO_Synapse_Targets)
###################################################################
################# IO ConnPC Synapse COUPLED #######################
###################################################################
S_IO_N_Coupled = Synapses(IO_Coupled, conn_N_PC_Coupled, method='euler',dt=dt)  # where f is 
S_IO_N_Coupled.connect(i=IO_PC_Synapse_Sources, j=IO_Copy_Synapse_Targets)
###################################################################
##################### IO PC Synapse COUPLED #######################
###################################################################
IO_PC_Synapse_Coupled = Synapses(IO_Coupled, PC_Coupled, on_pre =eqs_syn_IO_PC_pre, delay=2*ms,method = 'euler',dt=dt)
IO_PC_Synapse_Coupled.connect(i=IO_PC_Synapse_Sources,j=IO_PC_Synapse_Targets)
###################################################################
################# ConnPC PC Synapse COUPLED #######################
###################################################################
S_N_PC_Coupled = Synapses(conn_N_PC_Coupled,PC_Coupled, eqs_syn_bcm_s_n_pc, method='euler',dt=dt)
S_N_PC_Coupled.connect(i=N_Copy_order, j = Noise_PC_Synapse_Targets)
###################################################################
############## ConnPC Noise Synapse COUPLED #######################
###################################################################
S_PC_N_Coupled = Synapses(conn_N_PC_Coupled,Noise_extended_Coupled, 'weight_post = new_weight_pre : 1 (summed)', method='euler',dt=dt)
S_PC_N_Coupled.connect(i=N_Copy_order, j = Noise_PC_Synapse_Sources)
###################################################################
######################### Copy rate COUPLED #######################
###################################################################
copy_rate_Coupled = Synapses(Input_presyn_Coupled, conn_N_PC_Coupled, 'rho_PF_post = rho_presyn_pre : Hz (summed)', method='euler',dt=dt)
copy_rate_Coupled.connect(i = Noise_PC_Synapse_Sources, j=N_Copy_order)
###################################################################
######################## Copy Noise COUPLED #######################
###################################################################
copy_noise_Coupled = Synapses(Noise_extended_Coupled, conn_N_PC_Coupled, 'I_post = I_pre : amp (summed)', method='euler', dt=dt)
copy_noise_Coupled.connect(i = Noise_PC_Synapse_Sources, j=N_Copy_order)
copy_noise_Coupled.weight = Noise_PC_Synapse_Weights
###################################################################
################### PC Rate Synapse COUPLED #######################
########################################################`###########
S_PC_rate_Coupled = Synapses(PC_Coupled,conn_N_PC_Coupled, 'rho_PC_post = New_recent_rate_pre : Hz (summed)', method='euler',dt=dt)
S_PC_rate_Coupled.connect(i=Noise_PC_Synapse_Targets, j =N_Copy_order)

presyn_Noise_syn_Coupled = Synapses(Noise_extended_Coupled, Input_presyn_Coupled, 'noise_in_post = I_pre/nA : 1 (summed)',method='euler',dt=dt)  # where f is 
presyn_Noise_syn_Coupled.connect(j = 'i')

# %%
a_OU = 1.5
b_OU = .5
###################################################################
conn_N_PC.thresh_M = 200*Hz

IO.g_Ca_l =  0.375*mS/cm**2
IO.sigma_OU = 0.5*uA/cm**2
IO.I_OU = a_OU*uA/cm**2
IO.I0_OU = a_OU*uA/cm**2
###################################################################
conn_N_PC_Coupled.thresh_M = 200*Hz

IO_Coupled.g_Ca_l =  0.375*mS/cm**2
IO_Coupled.sigma_OU = 0.5*uA/cm**2
IO_Coupled.I_OU = a_OU*uA/cm**2
IO_Coupled.I0_OU = a_OU*uA/cm**2


###################################################################
########################### RUN ###################################
###################################################################
run(2*exp_run,report='text') # Report on the simulation
# Out:
# Starting simulation at t=0. s for a duration of 240. s
# 109.075 ms (0%) simulated in 10s, estimated 6h 6m 37s remaining.
# 219.45 ms (0%) simulated in 20s, estimated 6h 4m 16s remaining.
# 0.340375 s (0%) simulated in 30s, estimated 5h 52m 6s remaining.
# 0.4608 s (0%) simulated in 40s, estimated 5h 46m 36s remaining.
# 0.583275 s (0%) simulated in 50s, estimated 5h 42m 7s remaining.
# 0.702725 s (0%) simulated in 1m 0s, estimated 5h 40m 35s remaining.
# 0.831775 s (0%) simulated in 1m 10s, estimated 5h 35m 32s remaining.
# 0.955675 s (0%) simulated in 1m 20s, estimated 5h 33m 34s remaining.
# 1.095975 s (0%) simulated in 1m 30s, estimated 5h 27m 2s remaining.
# 1.2421 s (0%) simulated in 1m 40s, estimated 5h 20m 25s remaining.
# 1.3886 s (0%) simulated in 1m 50s, estimated 5h 15m 5s remaining.
# 1.534575 s (0%) simulated in 2m 0s, estimated 5h 10m 50s remaining.
# 1.682125 s (0%) simulated in 2m 10s, estimated 5h 7m 1s remaining.
# 1.8299 s (0%) simulated in 2m 20s, estimated 5h 3m 44s remaining.
# 1.960425 s (0%) simulated in 2m 30s, estimated 5h 3m 36s remaining.
# 2.09 s (0%) simulated in 2m 40s, estimated 5h 3m 36s remaining.
# 2.235425 s (0%) simulated in 2m 50s, estimated 5h 1m 24s remaining.
# 2.382275 s (0%) simulated in 3m 0s, estimated 4h 59m 16s remaining.
# 2.528525 s (1%) simulated in 3m 10s, estimated 4h 57m 27s remaining.
# 2.674825 s (1%) simulated in 3m 20s, estimated 4h 55m 47s remaining.
# 2.819075 s (1%) simulated in 3m 30s, estimated 4h 54m 31s remaining.
# 2.9439 s (1%) simulated in 3m 40s, estimated 4h 55m 18s remaining.
# 3.079625 s (1%) simulated in 3m 50s, estimated 4h 54m 57s remaining.
# 3.210375 s (1%) simulated in 4m 0s, estimated 4h 55m 4s remaining.
# 3.3489 s (1%) simulated in 4m 10s, estimated 4h 54m 28s remaining.
# 3.46965 s (1%) simulated in 4m 20s, estimated 4h 55m 27s remaining.
# 3.5981 s (1%) simulated in 4m 30s, estimated 4h 55m 42s remaining.
# 3.72645 s (1%) simulated in 4m 40s, estimated 4h 55m 55s remaining.
# 3.86065 s (1%) simulated in 4m 50s, estimated 4h 55m 40s remaining.
# 3.9889 s (1%) simulated in 5m 0s, estimated 4h 55m 52s remaining.
# 4.125275 s (1%) simulated in 5m 10s, estimated 4h 55m 27s remaining.
# 4.2572 s (1%) simulated in 5m 20s, estimated 4h 55m 22s remaining.
# 4.372825 s (1%) simulated in 5m 30s, estimated 4h 56m 24s remaining.
# 4.490725 s (1%) simulated in 5m 40s, estimated 4h 57m 13s remaining.
# 4.61955 s (1%) simulated in 5m 50s, estimated 4h 57m 16s remaining.
# 4.7567 s (1%) simulated in 6m 0s, estimated 4h 56m 46s remaining.
# 4.890675 s (2%) simulated in 6m 10s, estimated 4h 56m 29s remaining.
# 5.01545 s (2%) simulated in 6m 20s, estimated 4h 56m 46s remaining.
# 5.1467 s (2%) simulated in 6m 30s, estimated 4h 56m 38s remaining.
# 5.283925 s (2%) simulated in 6m 40s, estimated 4h 56m 10s remaining.
# 5.4163 s (2%) simulated in 6m 50s, estimated 4h 55m 59s remaining.
# 5.552675 s (2%) simulated in 7m 0s, estimated 4h 55m 35s remaining.
# 5.688525 s (2%) simulated in 7m 10s, estimated 4h 55m 14s remaining.
# 5.818475 s (2%) simulated in 7m 20s, estimated 4h 55m 11s remaining.
# 5.946025 s (2%) simulated in 7m 30s, estimated 4h 55m 15s remaining.
# 6.08215 s (2%) simulated in 7m 40s, estimated 4h 54m 53s remaining.
# 6.228875 s (2%) simulated in 7m 50s, estimated 4h 54m 1s remaining.
# 6.375825 s (2%) simulated in 8m 0s, estimated 4h 53m 10s remaining.
# 6.52215 s (2%) simulated in 8m 10s, estimated 4h 52m 23s remaining.
# 6.663925 s (2%) simulated in 8m 20s, estimated 4h 51m 49s remaining.
# 6.795025 s (2%) simulated in 8m 30s, estimated 4h 51m 45s remaining.
# 6.922875 s (2%) simulated in 8m 40s, estimated 4h 51m 49s remaining.
# 7.062675 s (2%) simulated in 8m 50s, estimated 4h 51m 22s remaining.
# 7.197325 s (2%) simulated in 9m 0s, estimated 4h 51m 9s remaining.
# 7.332775 s (3%) simulated in 9m 10s, estimated 4h 50m 53s remaining.
# 7.455275 s (3%) simulated in 9m 20s, estimated 4h 51m 9s remaining.
# 7.598725 s (3%) simulated in 9m 30s, estimated 4h 50m 35s remaining.
# 7.745475 s (3%) simulated in 9m 40s, estimated 4h 49m 54s remaining.
# 7.892775 s (3%) simulated in 9m 50s, estimated 4h 49m 12s remaining.
# 8.039125 s (3%) simulated in 10m 0s, estimated 4h 48m 34s remaining.
# 8.1868 s (3%) simulated in 10m 10s, estimated 4h 47m 54s remaining.
# 8.3278 s (3%) simulated in 10m 20s, estimated 4h 47m 30s remaining.
# 8.47485 s (3%) simulated in 10m 30s, estimated 4h 46m 53s remaining.
# 8.621 s (3%) simulated in 10m 40s, estimated 4h 46m 19s remaining.
# 8.768275 s (3%) simulated in 10m 50s, estimated 4h 45m 43s remaining.
# 8.915825 s (3%) simulated in 11m 0s, estimated 4h 45m 8s remaining.
# 9.0593 s (3%) simulated in 11m 10s, estimated 4h 44m 42s remaining.
# 9.176525 s (3%) simulated in 11m 20s, estimated 4h 45m 6s remaining.
# 9.3147 s (3%) simulated in 11m 30s, estimated 4h 44m 50s remaining.
# 9.459625 s (3%) simulated in 11m 40s, estimated 4h 44m 22s remaining.
# 9.60545 s (4%) simulated in 11m 50s, estimated 4h 43m 52s remaining.
# 9.752625 s (4%) simulated in 12m 0s, estimated 4h 43m 20s remaining.
# 9.900225 s (4%) simulated in 12m 10s, estimated 4h 42m 48s remaining.
# 10.047625 s (4%) simulated in 12m 20s, estimated 4h 42m 18s remaining.
# 10.1923 s (4%) simulated in 12m 30s, estimated 4h 41m 52s remaining.
# 10.327025 s (4%) simulated in 12m 40s, estimated 4h 41m 44s remaining.
# 10.46755 s (4%) simulated in 12m 50s, estimated 4h 41m 26s remaining.
# 10.60555 s (4%) simulated in 13m 0s, estimated 4h 41m 13s remaining.
# 10.744325 s (4%) simulated in 13m 10s, estimated 4h 40m 58s remaining.
# 10.882775 s (4%) simulated in 13m 20s, estimated 4h 40m 44s remaining.
# 11.024025 s (4%) simulated in 13m 30s, estimated 4h 40m 26s remaining.
# 11.164575 s (4%) simulated in 13m 40s, estimated 4h 40m 9s remaining.
# 11.304425 s (4%) simulated in 13m 50s, estimated 4h 39m 53s remaining.
# 11.44825 s (4%) simulated in 14m 0s, estimated 4h 39m 32s remaining.
# 11.593075 s (4%) simulated in 14m 10s, estimated 4h 39m 9s remaining.
# 11.731775 s (4%) simulated in 14m 20s, estimated 4h 38m 55s remaining.
# 11.8743 s (4%) simulated in 14m 30s, estimated 4h 38m 36s remaining.
# 12.01965 s (5%) simulated in 14m 40s, estimated 4h 38m 13s remaining.
# 12.1654 s (5%) simulated in 14m 50s, estimated 4h 37m 50s remaining.
# 12.31205 s (5%) simulated in 15m 0s, estimated 4h 37m 26s remaining.
# 12.4585 s (5%) simulated in 15m 10s, estimated 4h 37m 2s remaining.
# 12.5994 s (5%) simulated in 15m 20s, estimated 4h 36m 46s remaining.
# 12.747125 s (5%) simulated in 15m 30s, estimated 4h 36m 22s remaining.
# 12.89485 s (5%) simulated in 15m 40s, estimated 4h 35m 57s remaining.
# 13.042325 s (5%) simulated in 15m 50s, estimated 4h 35m 33s remaining.
# 13.187025 s (5%) simulated in 16m 0s, estimated 4h 35m 14s remaining.
# 13.33175 s (5%) simulated in 16m 10s, estimated 4h 34m 54s remaining.
# 13.47735 s (5%) simulated in 16m 20s, estimated 4h 34m 33s remaining.
# 13.62535 s (5%) simulated in 16m 30s, estimated 4h 34m 10s remaining.
# 13.7673 s (5%) simulated in 16m 40s, estimated 4h 33m 54s remaining.
# 13.9052 s (5%) simulated in 16m 50s, estimated 4h 33m 44s remaining.
# 14.04825 s (5%) simulated in 17m 0s, estimated 4h 33m 27s remaining.
# 14.1937 s (5%) simulated in 17m 10s, estimated 4h 33m 8s remaining.
# 14.339075 s (5%) simulated in 17m 20s, estimated 4h 32m 49s remaining.
# 14.486225 s (6%) simulated in 17m 30s, estimated 4h 32m 28s remaining.
# 14.63275 s (6%) simulated in 17m 40s, estimated 4h 32m 7s remaining.
# 14.77795 s (6%) simulated in 17m 50s, estimated 4h 31m 49s remaining.
# 14.915575 s (6%) simulated in 18m 0s, estimated 4h 31m 40s remaining.
# 15.0524 s (6%) simulated in 18m 10s, estimated 4h 31m 31s remaining.
# 15.19635 s (6%) simulated in 18m 20s, estimated 4h 31m 14s remaining.
# 15.3437 s (6%) simulated in 18m 30s, estimated 4h 30m 54s remaining.
# 15.4895 s (6%) simulated in 18m 40s, estimated 4h 30m 35s remaining.
# 15.63645 s (6%) simulated in 18m 50s, estimated 4h 30m 16s remaining.
# 15.783875 s (6%) simulated in 19m 0s, estimated 4h 29m 56s remaining.
# 15.9309 s (6%) simulated in 19m 10s, estimated 4h 29m 36s remaining.
# 16.077175 s (6%) simulated in 19m 20s, estimated 4h 29m 18s remaining.
# 16.2197 s (6%) simulated in 19m 30s, estimated 4h 29m 4s remaining.
# 16.359125 s (6%) simulated in 19m 40s, estimated 4h 28m 53s remaining.
# 16.487775 s (6%) simulated in 19m 50s, estimated 4h 28m 54s remaining.
# 16.632375 s (6%) simulated in 20m 0s, estimated 4h 28m 37s remaining.
# 16.7692 s (6%) simulated in 20m 10s, estimated 4h 28m 29s remaining.
# 16.9085 s (7%) simulated in 20m 20s, estimated 4h 28m 18s remaining.
# 17.0479 s (7%) simulated in 20m 30s, estimated 4h 28m 8s remaining.
# 17.191175 s (7%) simulated in 20m 40s, estimated 4h 27m 53s remaining.
# 17.330325 s (7%) simulated in 20m 50s, estimated 4h 27m 42s remaining.
# 17.46975 s (7%) simulated in 21m 0s, estimated 4h 27m 32s remaining.
# 17.610275 s (7%) simulated in 21m 10s, estimated 4h 27m 20s remaining.
# 17.751625 s (7%) simulated in 21m 20s, estimated 4h 27m 7s remaining.
# 17.8992 s (7%) simulated in 21m 30s, estimated 4h 26m 49s remaining.
# 18.044875 s (7%) simulated in 21m 40s, estimated 4h 26m 32s remaining.
# 18.1909 s (7%) simulated in 21m 50s, estimated 4h 26m 15s remaining.
# 18.33765 s (7%) simulated in 22m 0s, estimated 4h 25m 58s remaining.
# 18.477675 s (7%) simulated in 22m 10s, estimated 4h 25m 47s remaining.
# 18.61725 s (7%) simulated in 22m 20s, estimated 4h 25m 36s remaining.
# 18.756675 s (7%) simulated in 22m 30s, estimated 4h 25m 25s remaining.
# 18.89725 s (7%) simulated in 22m 40s, estimated 4h 25m 14s remaining.
# 19.039425 s (7%) simulated in 22m 50s, estimated 4h 25m 1s remaining.
# 19.178525 s (7%) simulated in 23m 0s, estimated 4h 24m 51s remaining.
# 19.31995 s (8%) simulated in 23m 10s, estimated 4h 24m 39s remaining.
# 19.4603 s (8%) simulated in 23m 20s, estimated 4h 24m 28s remaining.
# 19.6003 s (8%) simulated in 23m 30s, estimated 4h 24m 17s remaining.
# 19.74345 s (8%) simulated in 23m 40s, estimated 4h 24m 3s remaining.
# 19.88765 s (8%) simulated in 23m 50s, estimated 4h 23m 49s remaining.
# 20.027275 s (8%) simulated in 24m 0s, estimated 4h 23m 38s remaining.
# 20.1656 s (8%) simulated in 24m 10s, estimated 4h 23m 29s remaining.
# 20.297975 s (8%) simulated in 24m 20s, estimated 4h 23m 24s remaining.
# 20.43485 s (8%) simulated in 24m 30s, estimated 4h 23m 16s remaining.
# 20.5719 s (8%) simulated in 24m 40s, estimated 4h 23m 8s remaining.
# 20.713075 s (8%) simulated in 24m 50s, estimated 4h 22m 56s remaining.
# 20.854625 s (8%) simulated in 25m 0s, estimated 4h 22m 44s remaining.
# 20.995325 s (8%) simulated in 25m 10s, estimated 4h 22m 33s remaining.
# 21.13235 s (8%) simulated in 25m 20s, estimated 4h 22m 24s remaining.
# 21.269325 s (8%) simulated in 25m 30s, estimated 4h 22m 16s remaining.
# 21.407925 s (8%) simulated in 25m 40s, estimated 4h 22m 6s remaining.
# 21.54475 s (8%) simulated in 25m 50s, estimated 4h 21m 58s remaining.
# 21.6856 s (9%) simulated in 26m 0s, estimated 4h 21m 46s remaining.
# 21.822275 s (9%) simulated in 26m 10s, estimated 4h 21m 38s remaining.
# 21.960525 s (9%) simulated in 26m 20s, estimated 4h 21m 29s remaining.
# 22.0982 s (9%) simulated in 26m 30s, estimated 4h 21m 20s remaining.
# 22.237075 s (9%) simulated in 26m 40s, estimated 4h 21m 10s remaining.
# 22.37625 s (9%) simulated in 26m 50s, estimated 4h 21m 0s remaining.
# 22.514425 s (9%) simulated in 27m 0s, estimated 4h 20m 51s remaining.
# 22.6559 s (9%) simulated in 27m 10s, estimated 4h 20m 39s remaining.
# 22.789675 s (9%) simulated in 27m 20s, estimated 4h 20m 33s remaining.
# 22.9232 s (9%) simulated in 27m 30s, estimated 4h 20m 27s remaining.
# 23.055575 s (9%) simulated in 27m 40s, estimated 4h 20m 22s remaining.
# 23.19255 s (9%) simulated in 27m 50s, estimated 4h 20m 13s remaining.
# 23.332075 s (9%) simulated in 28m 0s, estimated 4h 20m 2s remaining.
# 23.471725 s (9%) simulated in 28m 10s, estimated 4h 19m 52s remaining.
# 23.60725 s (9%) simulated in 28m 20s, estimated 4h 19m 44s remaining.
# 23.74705 s (9%) simulated in 28m 30s, estimated 4h 19m 34s remaining.
# 23.889 s (9%) simulated in 28m 40s, estimated 4h 19m 21s remaining.
# 24.0305 s (10%) simulated in 28m 50s, estimated 4h 19m 10s remaining.
# 24.168825 s (10%) simulated in 29m 0s, estimated 4h 19m 0s remaining.
# 24.3053 s (10%) simulated in 29m 10s, estimated 4h 18m 52s remaining.
# 24.436125 s (10%) simulated in 29m 20s, estimated 4h 18m 47s remaining.
# 24.569125 s (10%) simulated in 29m 30s, estimated 4h 18m 42s remaining.
# 24.7063 s (10%) simulated in 29m 40s, estimated 4h 18m 33s remaining.
# 24.845675 s (10%) simulated in 29m 50s, estimated 4h 18m 22s remaining.
# 24.9835 s (10%) simulated in 30m 0s, estimated 4h 18m 13s remaining.
# 25.1238 s (10%) simulated in 30m 10s, estimated 4h 18m 2s remaining.
# 25.263525 s (10%) simulated in 30m 20s, estimated 4h 17m 51s remaining.
# 25.400775 s (10%) simulated in 30m 30s, estimated 4h 17m 42s remaining.
# 25.5377 s (10%) simulated in 30m 40s, estimated 4h 17m 34s remaining.
# 25.663725 s (10%) simulated in 30m 50s, estimated 4h 17m 32s remaining.
# 25.794775 s (10%) simulated in 31m 0s, estimated 4h 17m 27s remaining.
# 25.9187 s (10%) simulated in 31m 10s, estimated 4h 17m 27s remaining.
# 26.0553 s (10%) simulated in 31m 20s, estimated 4h 17m 19s remaining.
# 26.1854 s (10%) simulated in 31m 30s, estimated 4h 17m 14s remaining.
# 26.316975 s (10%) simulated in 31m 40s, estimated 4h 17m 9s remaining.
# 26.452475 s (11%) simulated in 31m 50s, estimated 4h 17m 1s remaining.
# 26.592375 s (11%) simulated in 32m 0s, estimated 4h 16m 50s remaining.
# 26.72795 s (11%) simulated in 32m 10s, estimated 4h 16m 42s remaining.
# 26.842825 s (11%) simulated in 32m 20s, estimated 4h 16m 47s remaining.
# 26.9684 s (11%) simulated in 32m 30s, estimated 4h 16m 45s remaining.
# 27.107275 s (11%) simulated in 32m 40s, estimated 4h 16m 35s remaining.
# 27.22725 s (11%) simulated in 32m 50s, estimated 4h 16m 36s remaining.
# 27.35935 s (11%) simulated in 33m 0s, estimated 4h 16m 30s remaining.
# 27.50525 s (11%) simulated in 33m 10s, estimated 4h 16m 15s remaining.
# 27.6524 s (11%) simulated in 33m 20s, estimated 4h 16m 0s remaining.
# 27.799925 s (11%) simulated in 33m 30s, estimated 4h 15m 44s remaining.
# 27.946775 s (11%) simulated in 33m 40s, estimated 4h 15m 29s remaining.
# 28.093275 s (11%) simulated in 33m 50s, estimated 4h 15m 14s remaining.
# 28.2397 s (11%) simulated in 34m 0s, estimated 4h 14m 59s remaining.
# 28.3871 s (11%) simulated in 34m 10s, estimated 4h 14m 43s remaining.
# 28.533875 s (11%) simulated in 34m 20s, estimated 4h 14m 28s remaining.
# 28.68165 s (11%) simulated in 34m 30s, estimated 4h 14m 13s remaining.
# 28.82925 s (12%) simulated in 34m 40s, estimated 4h 13m 57s remaining.
# 28.977025 s (12%) simulated in 34m 50s, estimated 4h 13m 42s remaining.
# 29.123325 s (12%) simulated in 35m 0s, estimated 4h 13m 27s remaining.
# 29.268425 s (12%) simulated in 35m 10s, estimated 4h 13m 13s remaining.
# 29.413725 s (12%) simulated in 35m 20s, estimated 4h 13m 0s remaining.
# 29.55865 s (12%) simulated in 35m 30s, estimated 4h 12m 46s remaining.
# 29.7048 s (12%) simulated in 35m 40s, estimated 4h 12m 32s remaining.
# 29.85225 s (12%) simulated in 35m 50s, estimated 4h 12m 17s remaining.
# 29.999075 s (12%) simulated in 36m 0s, estimated 4h 12m 2s remaining.
# 30.14655 s (12%) simulated in 36m 10s, estimated 4h 11m 47s remaining.
# 30.2924 s (12%) simulated in 36m 20s, estimated 4h 11m 33s remaining.
# 30.439925 s (12%) simulated in 36m 30s, estimated 4h 11m 18s remaining.
# 30.586625 s (12%) simulated in 36m 40s, estimated 4h 11m 4s remaining.
# 30.7334 s (12%) simulated in 36m 50s, estimated 4h 10m 50s remaining.
# 30.88015 s (12%) simulated in 37m 0s, estimated 4h 10m 35s remaining.
# 31.0264 s (12%) simulated in 37m 10s, estimated 4h 10m 21s remaining.
# 31.17335 s (12%) simulated in 37m 20s, estimated 4h 10m 7s remaining.
# 31.321025 s (13%) simulated in 37m 30s, estimated 4h 9m 52s remaining.
# 31.467225 s (13%) simulated in 37m 40s, estimated 4h 9m 38s remaining.
# 31.614475 s (13%) simulated in 37m 50s, estimated 4h 9m 24s remaining.
# 31.7604 s (13%) simulated in 38m 0s, estimated 4h 9m 10s remaining.
# 31.89585 s (13%) simulated in 38m 10s, estimated 4h 9m 3s remaining.
# 32.0268 s (13%) simulated in 38m 20s, estimated 4h 8m 57s remaining.
# 32.162925 s (13%) simulated in 38m 30s, estimated 4h 8m 49s remaining.
# 32.296675 s (13%) simulated in 38m 40s, estimated 4h 8m 42s remaining.
# 32.41945 s (13%) simulated in 38m 50s, estimated 4h 8m 40s remaining.
# 32.556775 s (13%) simulated in 39m 0s, estimated 4h 8m 31s remaining.
# 32.699225 s (13%) simulated in 39m 10s, estimated 4h 8m 20s remaining.
# 32.768025 s (13%) simulated in 39m 20s, estimated 4h 8m 47s remaining.
# 32.89045 s (13%) simulated in 39m 30s, estimated 4h 8m 46s remaining.
# 33.023725 s (13%) simulated in 39m 40s, estimated 4h 8m 39s remaining.
# 33.1543 s (13%) simulated in 39m 50s, estimated 4h 8m 33s remaining.
# 33.278625 s (13%) simulated in 40m 0s, estimated 4h 8m 31s remaining.
# 33.407925 s (13%) simulated in 40m 10s, estimated 4h 8m 25s remaining.
# 33.5243 s (13%) simulated in 40m 20s, estimated 4h 8m 27s remaining.
# 33.657875 s (14%) simulated in 40m 30s, estimated 4h 8m 19s remaining.
# 33.785275 s (14%) simulated in 40m 40s, estimated 4h 8m 15s remaining.
# 33.92425 s (14%) simulated in 40m 50s, estimated 4h 8m 5s remaining.
# 34.063775 s (14%) simulated in 41m 0s, estimated 4h 7m 54s remaining.
# 34.198775 s (14%) simulated in 41m 10s, estimated 4h 7m 46s remaining.
# 34.3309 s (14%) simulated in 41m 20s, estimated 4h 7m 39s remaining.
# 34.461625 s (14%) simulated in 41m 30s, estimated 4h 7m 33s remaining.
# 34.590025 s (14%) simulated in 41m 40s, estimated 4h 7m 28s remaining.
# 34.727625 s (14%) simulated in 41m 50s, estimated 4h 7m 19s remaining.
# 34.86155 s (14%) simulated in 42m 0s, estimated 4h 7m 11s remaining.
# 34.99275 s (14%) simulated in 42m 10s, estimated 4h 7m 4s remaining.
# 35.11815 s (14%) simulated in 42m 20s, estimated 4h 7m 1s remaining.
# 35.240775 s (14%) simulated in 42m 30s, estimated 4h 6m 58s remaining.
# 35.3609 s (14%) simulated in 42m 40s, estimated 4h 6m 57s remaining.
# 35.498775 s (14%) simulated in 42m 50s, estimated 4h 6m 47s remaining.
# 35.64425 s (14%) simulated in 43m 0s, estimated 4h 6m 34s remaining.
# 35.7908 s (14%) simulated in 43m 10s, estimated 4h 6m 20s remaining.
# 35.937 s (14%) simulated in 43m 20s, estimated 4h 6m 6s remaining.
# 36.0835 s (15%) simulated in 43m 30s, estimated 4h 5m 52s remaining.
# 36.22645 s (15%) simulated in 43m 40s, estimated 4h 5m 40s remaining.
# 36.3701 s (15%) simulated in 43m 50s, estimated 4h 5m 27s remaining.
# 36.5074 s (15%) simulated in 44m 0s, estimated 4h 5m 17s remaining.
# 36.6522 s (15%) simulated in 44m 10s, estimated 4h 5m 4s remaining.
# 36.799175 s (15%) simulated in 44m 20s, estimated 4h 4m 50s remaining.
# 36.945125 s (15%) simulated in 44m 30s, estimated 4h 4m 37s remaining.
# 37.08325 s (15%) simulated in 44m 40s, estimated 4h 4m 27s remaining.
# 37.20365 s (15%) simulated in 44m 50s, estimated 4h 4m 25s remaining.
# 37.348725 s (15%) simulated in 45m 0s, estimated 4h 4m 12s remaining.
# 37.4858 s (15%) simulated in 45m 10s, estimated 4h 4m 3s remaining.
# 37.611375 s (15%) simulated in 45m 20s, estimated 4h 3m 58s remaining.
# 37.754325 s (15%) simulated in 45m 30s, estimated 4h 3m 46s remaining.
# 37.8909 s (15%) simulated in 45m 40s, estimated 4h 3m 37s remaining.
# 38.03365 s (15%) simulated in 45m 50s, estimated 4h 3m 25s remaining.
# 38.16085 s (15%) simulated in 46m 0s, estimated 4h 3m 20s remaining.
# 38.298325 s (15%) simulated in 46m 10s, estimated 4h 3m 10s remaining.
# 38.438075 s (16%) simulated in 46m 20s, estimated 4h 3m 0s remaining.
# 38.578875 s (16%) simulated in 46m 30s, estimated 4h 2m 49s remaining.
# 38.72345 s (16%) simulated in 46m 40s, estimated 4h 2m 36s remaining.
# 38.867275 s (16%) simulated in 46m 50s, estimated 4h 2m 23s remaining.
# 39.005425 s (16%) simulated in 47m 0s, estimated 4h 2m 13s remaining.
# 39.13135 s (16%) simulated in 47m 10s, estimated 4h 2m 9s remaining.
# 39.257375 s (16%) simulated in 47m 20s, estimated 4h 2m 4s remaining.
# 39.386325 s (16%) simulated in 47m 30s, estimated 4h 1m 58s remaining.
# 39.511725 s (16%) simulated in 47m 40s, estimated 4h 1m 54s remaining.
# 39.640225 s (16%) simulated in 47m 50s, estimated 4h 1m 48s remaining.
# 39.77695 s (16%) simulated in 48m 0s, estimated 4h 1m 39s remaining.
# 39.92815 s (16%) simulated in 48m 10s, estimated 4h 1m 23s remaining.
# 40.071425 s (16%) simulated in 48m 20s, estimated 4h 1m 11s remaining.
# 40.218775 s (16%) simulated in 48m 30s, estimated 4h 0m 57s remaining.
# 40.368625 s (16%) simulated in 48m 40s, estimated 4h 0m 42s remaining.
# 40.5198 s (16%) simulated in 48m 50s, estimated 4h 0m 26s remaining.
# 40.6748 s (16%) simulated in 49m 0s, estimated 4h 0m 9s remaining.
# 40.829525 s (17%) simulated in 49m 10s, estimated 3h 59m 52s remaining.
# 40.969125 s (17%) simulated in 49m 20s, estimated 3h 59m 42s remaining.
# 41.107975 s (17%) simulated in 49m 30s, estimated 3h 59m 32s remaining.
# 41.242925 s (17%) simulated in 49m 40s, estimated 3h 59m 23s remaining.
# 41.37815 s (17%) simulated in 49m 50s, estimated 3h 59m 14s remaining.
# 41.521925 s (17%) simulated in 50m 0s, estimated 3h 59m 2s remaining.
# 41.6617 s (17%) simulated in 50m 10s, estimated 3h 58m 52s remaining.
# 41.79215 s (17%) simulated in 50m 20s, estimated 3h 58m 45s remaining.
# 41.92585 s (17%) simulated in 50m 30s, estimated 3h 58m 37s remaining.
# 42.059375 s (17%) simulated in 50m 40s, estimated 3h 58m 29s remaining.
# 42.178575 s (17%) simulated in 50m 50s, estimated 3h 58m 27s remaining.
# 42.310525 s (17%) simulated in 51m 0s, estimated 3h 58m 19s remaining.
# 42.43745 s (17%) simulated in 51m 10s, estimated 3h 58m 14s remaining.
# 42.566975 s (17%) simulated in 51m 20s, estimated 3h 58m 7s remaining.
# 42.69985 s (17%) simulated in 51m 30s, estimated 3h 58m 0s remaining.
# 42.82325 s (17%) simulated in 51m 40s, estimated 3h 57m 56s remaining.
# 42.949125 s (17%) simulated in 51m 50s, estimated 3h 57m 51s remaining.
# 43.073525 s (17%) simulated in 52m 0s, estimated 3h 57m 46s remaining.
# 43.20275 s (18%) simulated in 52m 10s, estimated 3h 57m 40s remaining.
# 43.332275 s (18%) simulated in 52m 20s, estimated 3h 57m 33s remaining.
# 43.462825 s (18%) simulated in 52m 30s, estimated 3h 57m 26s remaining.
# 43.588525 s (18%) simulated in 52m 40s, estimated 3h 57m 21s remaining.
# 43.71505 s (18%) simulated in 52m 50s, estimated 3h 57m 16s remaining.
# 43.84105 s (18%) simulated in 53m 0s, estimated 3h 57m 10s remaining.
# 43.971 s (18%) simulated in 53m 10s, estimated 3h 57m 3s remaining.
# 44.096525 s (18%) simulated in 53m 20s, estimated 3h 56m 58s remaining.
# 44.221 s (18%) simulated in 53m 30s, estimated 3h 56m 53s remaining.
# 44.34935 s (18%) simulated in 53m 40s, estimated 3h 56m 47s remaining.
# 44.4758 s (18%) simulated in 53m 50s, estimated 3h 56m 42s remaining.
# 44.599675 s (18%) simulated in 54m 0s, estimated 3h 56m 37s remaining.
# 44.727825 s (18%) simulated in 54m 10s, estimated 3h 56m 31s remaining.
# 44.853275 s (18%) simulated in 54m 20s, estimated 3h 56m 25s remaining.
# 44.974175 s (18%) simulated in 54m 30s, estimated 3h 56m 22s remaining.
# 45.101425 s (18%) simulated in 54m 40s, estimated 3h 56m 16s remaining.
# 45.22825 s (18%) simulated in 54m 50s, estimated 3h 56m 10s remaining.
# 45.352675 s (18%) simulated in 55m 0s, estimated 3h 56m 5s remaining.
# 45.479625 s (18%) simulated in 55m 10s, estimated 3h 55m 59s remaining.
# 45.6042 s (19%) simulated in 55m 20s, estimated 3h 55m 54s remaining.
# 45.72875 s (19%) simulated in 55m 30s, estimated 3h 55m 49s remaining.
# 45.8553 s (19%) simulated in 55m 40s, estimated 3h 55m 43s remaining.
# 45.982875 s (19%) simulated in 55m 50s, estimated 3h 55m 37s remaining.
# 46.1124 s (19%) simulated in 56m 0s, estimated 3h 55m 30s remaining.
# 46.23985 s (19%) simulated in 56m 10s, estimated 3h 55m 23s remaining.
# 46.36335 s (19%) simulated in 56m 20s, estimated 3h 55m 18s remaining.
# 46.4896 s (19%) simulated in 56m 30s, estimated 3h 55m 13s remaining.
# 46.619025 s (19%) simulated in 56m 40s, estimated 3h 55m 5s remaining.
# 46.743025 s (19%) simulated in 56m 50s, estimated 3h 55m 0s remaining.
# 46.8699 s (19%) simulated in 57m 0s, estimated 3h 54m 54s remaining.
# 46.996275 s (19%) simulated in 57m 10s, estimated 3h 54m 48s remaining.
# 47.122 s (19%) simulated in 57m 20s, estimated 3h 54m 42s remaining.
# 47.248675 s (19%) simulated in 57m 30s, estimated 3h 54m 36s remaining.
# 47.378025 s (19%) simulated in 57m 40s, estimated 3h 54m 29s remaining.
# 47.50675 s (19%) simulated in 57m 50s, estimated 3h 54m 22s remaining.
# 47.6336 s (19%) simulated in 58m 0s, estimated 3h 54m 16s remaining.
# 47.7608 s (19%) simulated in 58m 10s, estimated 3h 54m 9s remaining.
# 47.8864 s (19%) simulated in 58m 20s, estimated 3h 54m 3s remaining.
# 48.0138 s (20%) simulated in 58m 30s, estimated 3h 53m 57s remaining.
# 48.140525 s (20%) simulated in 58m 40s, estimated 3h 53m 50s remaining.
# 48.266625 s (20%) simulated in 58m 50s, estimated 3h 53m 44s remaining.
# 48.39505 s (20%) simulated in 59m 0s, estimated 3h 53m 37s remaining.
# 48.5236 s (20%) simulated in 59m 10s, estimated 3h 53m 30s remaining.
# 48.6589 s (20%) simulated in 59m 20s, estimated 3h 53m 21s remaining.
# 48.796 s (20%) simulated in 59m 30s, estimated 3h 53m 11s remaining.
# 48.9306 s (20%) simulated in 59m 40s, estimated 3h 53m 1s remaining.
# 49.067825 s (20%) simulated in 59m 50s, estimated 3h 52m 51s remaining.
# 49.204075 s (20%) simulated in 1h 0m 0s, estimated 3h 52m 41s remaining.
# 49.3382 s (20%) simulated in 1h 0m 10s, estimated 3h 52m 32s remaining.
# 49.463775 s (20%) simulated in 1h 0m 20s, estimated 3h 52m 26s remaining.
# 49.592325 s (20%) simulated in 1h 0m 30s, estimated 3h 52m 19s remaining.
# 49.7237 s (20%) simulated in 1h 0m 40s, estimated 3h 52m 11s remaining.
# 49.85205 s (20%) simulated in 1h 0m 50s, estimated 3h 52m 4s remaining.
# 49.982575 s (20%) simulated in 1h 1m 0s, estimated 3h 51m 56s remaining.
# 50.1047 s (20%) simulated in 1h 1m 10s, estimated 3h 51m 51s remaining.
# 50.2308 s (20%) simulated in 1h 1m 20s, estimated 3h 51m 45s remaining.
# 50.353 s (20%) simulated in 1h 1m 30s, estimated 3h 51m 40s remaining.
# 50.481275 s (21%) simulated in 1h 1m 40s, estimated 3h 51m 33s remaining.
# 50.6106 s (21%) simulated in 1h 1m 50s, estimated 3h 51m 25s remaining.
# 50.739675 s (21%) simulated in 1h 2m 0s, estimated 3h 51m 18s remaining.
# 50.875275 s (21%) simulated in 1h 2m 10s, estimated 3h 51m 8s remaining.
# 51.006075 s (21%) simulated in 1h 2m 20s, estimated 3h 51m 0s remaining.
# 51.13445 s (21%) simulated in 1h 2m 30s, estimated 3h 50m 52s remaining.
# 51.2637 s (21%) simulated in 1h 2m 40s, estimated 3h 50m 45s remaining.
# 51.3935 s (21%) simulated in 1h 2m 50s, estimated 3h 50m 37s remaining.
# 51.523675 s (21%) simulated in 1h 3m 0s, estimated 3h 50m 29s remaining.
# 51.65425 s (21%) simulated in 1h 3m 10s, estimated 3h 50m 21s remaining.
# 51.78475 s (21%) simulated in 1h 3m 20s, estimated 3h 50m 13s remaining.
# 51.905225 s (21%) simulated in 1h 3m 30s, estimated 3h 50m 9s remaining.
# 52.029225 s (21%) simulated in 1h 3m 40s, estimated 3h 50m 3s remaining.
# 52.1608 s (21%) simulated in 1h 3m 50s, estimated 3h 49m 54s remaining.
# 52.2881 s (21%) simulated in 1h 4m 0s, estimated 3h 49m 47s remaining.
# 52.40325 s (21%) simulated in 1h 4m 10s, estimated 3h 49m 44s remaining.
# 52.52445 s (21%) simulated in 1h 4m 20s, estimated 3h 49m 39s remaining.
# 52.64675 s (21%) simulated in 1h 4m 30s, estimated 3h 49m 34s remaining.
# 52.76965 s (21%) simulated in 1h 4m 40s, estimated 3h 49m 28s remaining.
# 52.889425 s (22%) simulated in 1h 4m 50s, estimated 3h 49m 24s remaining.
# 53.017625 s (22%) simulated in 1h 5m 0s, estimated 3h 49m 16s remaining.
# 53.145275 s (22%) simulated in 1h 5m 10s, estimated 3h 49m 9s remaining.
# 53.273625 s (22%) simulated in 1h 5m 20s, estimated 3h 49m 2s remaining.
# 53.4004 s (22%) simulated in 1h 5m 30s, estimated 3h 48m 55s remaining.
# 53.5295 s (22%) simulated in 1h 5m 40s, estimated 3h 48m 47s remaining.
# 53.647625 s (22%) simulated in 1h 5m 50s, estimated 3h 48m 43s remaining.
# 53.771125 s (22%) simulated in 1h 6m 0s, estimated 3h 48m 37s remaining.
# 53.882525 s (22%) simulated in 1h 6m 10s, estimated 3h 48m 35s remaining.
# 54.0107 s (22%) simulated in 1h 6m 20s, estimated 3h 48m 27s remaining.
# 54.112825 s (22%) simulated in 1h 6m 30s, estimated 3h 48m 28s remaining.
# 54.224525 s (22%) simulated in 1h 6m 40s, estimated 3h 48m 26s remaining.
# 54.344625 s (22%) simulated in 1h 6m 50s, estimated 3h 48m 21s remaining.
# 54.463475 s (22%) simulated in 1h 7m 0s, estimated 3h 48m 16s remaining.
# 54.578325 s (22%) simulated in 1h 7m 10s, estimated 3h 48m 13s remaining.
# 54.695375 s (22%) simulated in 1h 7m 20s, estimated 3h 48m 9s remaining.
# 54.822575 s (22%) simulated in 1h 7m 30s, estimated 3h 48m 2s remaining.
# 54.95205 s (22%) simulated in 1h 7m 40s, estimated 3h 47m 54s remaining.
# 55.0836 s (22%) simulated in 1h 7m 50s, estimated 3h 47m 45s remaining.
# 55.214875 s (23%) simulated in 1h 8m 0s, estimated 3h 47m 36s remaining.
# 55.346475 s (23%) simulated in 1h 8m 10s, estimated 3h 47m 27s remaining.
# 55.48385 s (23%) simulated in 1h 8m 20s, estimated 3h 47m 17s remaining.
# 55.623225 s (23%) simulated in 1h 8m 30s, estimated 3h 47m 5s remaining.
# 55.754325 s (23%) simulated in 1h 8m 40s, estimated 3h 46m 57s remaining.
# 55.88165 s (23%) simulated in 1h 8m 50s, estimated 3h 46m 49s remaining.
# 56.011925 s (23%) simulated in 1h 9m 0s, estimated 3h 46m 41s remaining.
# 56.14705 s (23%) simulated in 1h 9m 10s, estimated 3h 46m 31s remaining.
# 56.277425 s (23%) simulated in 1h 9m 20s, estimated 3h 46m 22s remaining.
# 56.4085 s (23%) simulated in 1h 9m 30s, estimated 3h 46m 14s remaining.
# 56.54535 s (23%) simulated in 1h 9m 40s, estimated 3h 46m 3s remaining.
# 56.68255 s (23%) simulated in 1h 9m 50s, estimated 3h 45m 53s remaining.
# 56.816625 s (23%) simulated in 1h 10m 0s, estimated 3h 45m 43s remaining.
# 56.95085 s (23%) simulated in 1h 10m 10s, estimated 3h 45m 33s remaining.
# 57.08245 s (23%) simulated in 1h 10m 20s, estimated 3h 45m 24s remaining.
# 57.208425 s (23%) simulated in 1h 10m 30s, estimated 3h 45m 17s remaining.
# 57.338125 s (23%) simulated in 1h 10m 40s, estimated 3h 45m 9s remaining.
# 57.46675 s (23%) simulated in 1h 10m 50s, estimated 3h 45m 1s remaining.
# 57.59685 s (23%) simulated in 1h 11m 0s, estimated 3h 44m 53s remaining.
# 57.729725 s (24%) simulated in 1h 11m 10s, estimated 3h 44m 43s remaining.
# 57.860025 s (24%) simulated in 1h 11m 20s, estimated 3h 44m 35s remaining.
# 57.999325 s (24%) simulated in 1h 11m 30s, estimated 3h 44m 24s remaining.
# 58.126625 s (24%) simulated in 1h 11m 40s, estimated 3h 44m 16s remaining.
# 58.25565 s (24%) simulated in 1h 11m 50s, estimated 3h 44m 8s remaining.
# 58.3838 s (24%) simulated in 1h 12m 0s, estimated 3h 44m 0s remaining.
# 58.51175 s (24%) simulated in 1h 12m 10s, estimated 3h 43m 52s remaining.
# 58.642875 s (24%) simulated in 1h 12m 20s, estimated 3h 43m 43s remaining.
# 58.771675 s (24%) simulated in 1h 12m 30s, estimated 3h 43m 35s remaining.
# 58.9014 s (24%) simulated in 1h 12m 40s, estimated 3h 43m 27s remaining.
# 59.028775 s (24%) simulated in 1h 12m 50s, estimated 3h 43m 19s remaining.
# 59.156375 s (24%) simulated in 1h 13m 0s, estimated 3h 43m 12s remaining.
# 59.28005 s (24%) simulated in 1h 13m 10s, estimated 3h 43m 5s remaining.
# 59.408675 s (24%) simulated in 1h 13m 20s, estimated 3h 42m 57s remaining.
# 59.538375 s (24%) simulated in 1h 13m 30s, estimated 3h 42m 48s remaining.
# 59.6706 s (24%) simulated in 1h 13m 40s, estimated 3h 42m 39s remaining.
# 59.803525 s (24%) simulated in 1h 13m 50s, estimated 3h 42m 30s remaining.
# 59.9364 s (24%) simulated in 1h 14m 0s, estimated 3h 42m 21s remaining.
# 60.063675 s (25%) simulated in 1h 14m 10s, estimated 3h 42m 13s remaining.
# 60.191675 s (25%) simulated in 1h 14m 20s, estimated 3h 42m 5s remaining.
# 60.31745 s (25%) simulated in 1h 14m 30s, estimated 3h 41m 58s remaining.
# 60.44875 s (25%) simulated in 1h 14m 40s, estimated 3h 41m 49s remaining.
# 60.5834 s (25%) simulated in 1h 14m 50s, estimated 3h 41m 39s remaining.
# 60.716275 s (25%) simulated in 1h 15m 0s, estimated 3h 41m 29s remaining.
# 60.84375 s (25%) simulated in 1h 15m 10s, estimated 3h 41m 21s remaining.
# 60.968775 s (25%) simulated in 1h 15m 20s, estimated 3h 41m 14s remaining.
# 61.099525 s (25%) simulated in 1h 15m 30s, estimated 3h 41m 6s remaining.
# 61.2254 s (25%) simulated in 1h 15m 40s, estimated 3h 40m 58s remaining.
# 61.3517 s (25%) simulated in 1h 15m 50s, estimated 3h 40m 51s remaining.
# 61.47485 s (25%) simulated in 1h 16m 0s, estimated 3h 40m 44s remaining.
# 61.602325 s (25%) simulated in 1h 16m 10s, estimated 3h 40m 36s remaining.
# 61.72675 s (25%) simulated in 1h 16m 20s, estimated 3h 40m 29s remaining.
# 61.852725 s (25%) simulated in 1h 16m 30s, estimated 3h 40m 22s remaining.
# 61.9773 s (25%) simulated in 1h 16m 40s, estimated 3h 40m 15s remaining.
# 62.109075 s (25%) simulated in 1h 16m 50s, estimated 3h 40m 5s remaining.
# 62.237475 s (25%) simulated in 1h 17m 0s, estimated 3h 39m 57s remaining.
# 62.36215 s (25%) simulated in 1h 17m 10s, estimated 3h 39m 50s remaining.
# 62.4933 s (26%) simulated in 1h 17m 20s, estimated 3h 39m 41s remaining.
# 62.622475 s (26%) simulated in 1h 17m 30s, estimated 3h 39m 33s remaining.
# 62.755325 s (26%) simulated in 1h 17m 40s, estimated 3h 39m 23s remaining.
# 62.8835 s (26%) simulated in 1h 17m 50s, estimated 3h 39m 15s remaining.
# 63.0058 s (26%) simulated in 1h 18m 0s, estimated 3h 39m 9s remaining.
# 63.1305 s (26%) simulated in 1h 18m 10s, estimated 3h 39m 1s remaining.
# 63.25645 s (26%) simulated in 1h 18m 20s, estimated 3h 38m 54s remaining.
# 63.385625 s (26%) simulated in 1h 18m 30s, estimated 3h 38m 45s remaining.
# 63.5128 s (26%) simulated in 1h 18m 40s, estimated 3h 38m 37s remaining.
# 63.641975 s (26%) simulated in 1h 18m 50s, estimated 3h 38m 29s remaining.
# 63.7684 s (26%) simulated in 1h 19m 0s, estimated 3h 38m 21s remaining.
# 63.905575 s (26%) simulated in 1h 19m 10s, estimated 3h 38m 10s remaining.
# 64.04055 s (26%) simulated in 1h 19m 20s, estimated 3h 38m 0s remaining.
# 64.1698 s (26%) simulated in 1h 19m 30s, estimated 3h 37m 52s remaining.
# 64.305075 s (26%) simulated in 1h 19m 40s, estimated 3h 37m 42s remaining.
# 64.4408 s (26%) simulated in 1h 19m 50s, estimated 3h 37m 31s remaining.
# 64.57185 s (26%) simulated in 1h 20m 0s, estimated 3h 37m 22s remaining.
# 64.6997 s (26%) simulated in 1h 20m 10s, estimated 3h 37m 14s remaining.
# 64.827825 s (27%) simulated in 1h 20m 20s, estimated 3h 37m 6s remaining.
# 64.95375 s (27%) simulated in 1h 20m 30s, estimated 3h 36m 58s remaining.
# 65.08945 s (27%) simulated in 1h 20m 40s, estimated 3h 36m 48s remaining.
# 65.2182 s (27%) simulated in 1h 20m 50s, estimated 3h 36m 39s remaining.
# 65.341175 s (27%) simulated in 1h 21m 0s, estimated 3h 36m 33s remaining.
# 65.436725 s (27%) simulated in 1h 21m 10s, estimated 3h 36m 33s remaining.
# 65.536025 s (27%) simulated in 1h 21m 38s, estimated 3h 37m 21s remaining.
# 65.664275 s (27%) simulated in 1h 21m 48s, estimated 3h 37m 12s remaining.
# 65.793375 s (27%) simulated in 1h 21m 58s, estimated 3h 37m 4s remaining.
# 65.895175 s (27%) simulated in 1h 22m 8s, estimated 3h 37m 2s remaining.
# 66.0233 s (27%) simulated in 1h 22m 18s, estimated 3h 36m 54s remaining.
# 66.154325 s (27%) simulated in 1h 22m 28s, estimated 3h 36m 44s remaining.
# 66.2738 s (27%) simulated in 1h 22m 38s, estimated 3h 36m 38s remaining.
# 66.388175 s (27%) simulated in 1h 22m 48s, estimated 3h 36m 34s remaining.
# 66.527375 s (27%) simulated in 1h 22m 58s, estimated 3h 36m 22s remaining.
# 66.666425 s (27%) simulated in 1h 23m 8s, estimated 3h 36m 11s remaining.
# 66.807775 s (27%) simulated in 1h 23m 18s, estimated 3h 35m 58s remaining.
# 66.9275 s (27%) simulated in 1h 23m 28s, estimated 3h 35m 52s remaining.
# 67.04775 s (27%) simulated in 1h 23m 38s, estimated 3h 35m 46s remaining.
# 67.180225 s (27%) simulated in 1h 23m 48s, estimated 3h 35m 36s remaining.
# 67.323075 s (28%) simulated in 1h 23m 58s, estimated 3h 35m 24s remaining.
# 67.462175 s (28%) simulated in 1h 24m 8s, estimated 3h 35m 12s remaining.
# 67.60075 s (28%) simulated in 1h 24m 18s, estimated 3h 35m 1s remaining.
# 67.730175 s (28%) simulated in 1h 24m 28s, estimated 3h 34m 52s remaining.
# 67.866975 s (28%) simulated in 1h 24m 38s, estimated 3h 34m 41s remaining.
# 68.00565 s (28%) simulated in 1h 24m 48s, estimated 3h 34m 30s remaining.
# 68.13035 s (28%) simulated in 1h 24m 58s, estimated 3h 34m 22s remaining.
# 68.2713 s (28%) simulated in 1h 25m 8s, estimated 3h 34m 10s remaining.
# 68.4197 s (28%) simulated in 1h 25m 18s, estimated 3h 33m 56s remaining.
# 68.565525 s (28%) simulated in 1h 25m 28s, estimated 3h 33m 43s remaining.
# 68.702875 s (28%) simulated in 1h 25m 38s, estimated 3h 33m 32s remaining.
# 68.844 s (28%) simulated in 1h 25m 48s, estimated 3h 33m 20s remaining.
# 68.98905 s (28%) simulated in 1h 25m 58s, estimated 3h 33m 7s remaining.
# 69.133775 s (28%) simulated in 1h 26m 8s, estimated 3h 32m 55s remaining.
# 69.271375 s (28%) simulated in 1h 26m 18s, estimated 3h 32m 44s remaining.
# 69.39975 s (28%) simulated in 1h 26m 28s, estimated 3h 32m 35s remaining.
# 69.532475 s (28%) simulated in 1h 26m 38s, estimated 3h 32m 25s remaining.
# 69.639075 s (29%) simulated in 1h 26m 48s, estimated 3h 32m 22s remaining.
# 69.786525 s (29%) simulated in 1h 26m 58s, estimated 3h 32m 9s remaining.
# 69.93605 s (29%) simulated in 1h 27m 8s, estimated 3h 31m 55s remaining.
# 70.08475 s (29%) simulated in 1h 27m 18s, estimated 3h 31m 41s remaining.
# 70.23175 s (29%) simulated in 1h 27m 28s, estimated 3h 31m 27s remaining.
# 70.381125 s (29%) simulated in 1h 27m 38s, estimated 3h 31m 13s remaining.
# 70.53085 s (29%) simulated in 1h 27m 48s, estimated 3h 30m 59s remaining.
# 70.684525 s (29%) simulated in 1h 27m 58s, estimated 3h 30m 44s remaining.
# 70.83835 s (29%) simulated in 1h 28m 8s, estimated 3h 30m 29s remaining.
# 70.9896 s (29%) simulated in 1h 28m 18s, estimated 3h 30m 15s remaining.
# 71.1433 s (29%) simulated in 1h 28m 28s, estimated 3h 30m 0s remaining.
# 71.29155 s (29%) simulated in 1h 28m 38s, estimated 3h 29m 46s remaining.
# 71.44285 s (29%) simulated in 1h 28m 48s, estimated 3h 29m 32s remaining.
# 71.5978 s (29%) simulated in 1h 28m 58s, estimated 3h 29m 17s remaining.
# 71.7531 s (29%) simulated in 1h 29m 8s, estimated 3h 29m 2s remaining.
# 71.90855 s (29%) simulated in 1h 29m 18s, estimated 3h 28m 46s remaining.
# 72.063475 s (30%) simulated in 1h 29m 28s, estimated 3h 28m 31s remaining.
# 72.20905 s (30%) simulated in 1h 29m 38s, estimated 3h 28m 18s remaining.
# 72.3665 s (30%) simulated in 1h 29m 48s, estimated 3h 28m 3s remaining.
# 72.5228 s (30%) simulated in 1h 29m 58s, estimated 3h 27m 47s remaining.
# 72.679825 s (30%) simulated in 1h 30m 8s, estimated 3h 27m 32s remaining.
# 72.8363 s (30%) simulated in 1h 30m 18s, estimated 3h 27m 16s remaining.
# 72.96935 s (30%) simulated in 1h 30m 28s, estimated 3h 27m 7s remaining.
# 73.109675 s (30%) simulated in 1h 30m 38s, estimated 3h 26m 55s remaining.
# 73.266225 s (30%) simulated in 1h 30m 48s, estimated 3h 26m 40s remaining.
# 73.42445 s (30%) simulated in 1h 30m 58s, estimated 3h 26m 24s remaining.
# 73.569275 s (30%) simulated in 1h 31m 8s, estimated 3h 26m 11s remaining.
# 73.69175 s (30%) simulated in 1h 31m 18s, estimated 3h 26m 4s remaining.
# 73.848525 s (30%) simulated in 1h 31m 28s, estimated 3h 25m 49s remaining.
# 74.0065 s (30%) simulated in 1h 31m 38s, estimated 3h 25m 33s remaining.
# 74.163225 s (30%) simulated in 1h 31m 48s, estimated 3h 25m 18s remaining.
# 74.3209 s (30%) simulated in 1h 31m 58s, estimated 3h 25m 3s remaining.
# 74.478675 s (31%) simulated in 1h 32m 8s, estimated 3h 24m 47s remaining.
# 74.637175 s (31%) simulated in 1h 32m 18s, estimated 3h 24m 31s remaining.
# 74.7951 s (31%) simulated in 1h 32m 28s, estimated 3h 24m 16s remaining.
# 74.95215 s (31%) simulated in 1h 32m 38s, estimated 3h 24m 1s remaining.
# 75.109825 s (31%) simulated in 1h 32m 48s, estimated 3h 23m 45s remaining.
# 75.2682 s (31%) simulated in 1h 32m 58s, estimated 3h 23m 30s remaining.
# 75.42655 s (31%) simulated in 1h 33m 8s, estimated 3h 23m 14s remaining.
# 75.585275 s (31%) simulated in 1h 33m 18s, estimated 3h 22m 58s remaining.
# 75.73145 s (31%) simulated in 1h 33m 28s, estimated 3h 22m 46s remaining.
# 75.8708 s (31%) simulated in 1h 33m 38s, estimated 3h 22m 35s remaining.
# 76.000425 s (31%) simulated in 1h 33m 48s, estimated 3h 22m 26s remaining.
# 76.1451 s (31%) simulated in 1h 33m 58s, estimated 3h 22m 14s remaining.
# 76.291825 s (31%) simulated in 1h 34m 8s, estimated 3h 22m 1s remaining.
# 76.431475 s (31%) simulated in 1h 34m 18s, estimated 3h 21m 50s remaining.
# 76.583575 s (31%) simulated in 1h 34m 28s, estimated 3h 21m 36s remaining.
# 76.7247 s (31%) simulated in 1h 34m 38s, estimated 3h 21m 25s remaining.
# 76.870225 s (32%) simulated in 1h 34m 48s, estimated 3h 21m 12s remaining.
# 77.0116 s (32%) simulated in 1h 34m 58s, estimated 3h 21m 1s remaining.
# 77.161675 s (32%) simulated in 1h 35m 8s, estimated 3h 20m 47s remaining.
# 77.3157 s (32%) simulated in 1h 35m 18s, estimated 3h 20m 33s remaining.
# 77.46785 s (32%) simulated in 1h 35m 28s, estimated 3h 20m 19s remaining.
# 77.61065 s (32%) simulated in 1h 35m 38s, estimated 3h 20m 7s remaining.
# 77.753825 s (32%) simulated in 1h 35m 48s, estimated 3h 19m 56s remaining.
# 77.89715 s (32%) simulated in 1h 35m 58s, estimated 3h 19m 44s remaining.
# 78.0366 s (32%) simulated in 1h 36m 8s, estimated 3h 19m 33s remaining.
# 78.179025 s (32%) simulated in 1h 36m 18s, estimated 3h 19m 21s remaining.
# 78.324275 s (32%) simulated in 1h 36m 28s, estimated 3h 19m 9s remaining.
# 78.4664 s (32%) simulated in 1h 36m 38s, estimated 3h 18m 57s remaining.
# 78.607675 s (32%) simulated in 1h 36m 48s, estimated 3h 18m 46s remaining.
# 78.748925 s (32%) simulated in 1h 36m 58s, estimated 3h 18m 35s remaining.
# 78.882875 s (32%) simulated in 1h 37m 8s, estimated 3h 18m 25s remaining.
# 79.016575 s (32%) simulated in 1h 37m 18s, estimated 3h 18m 15s remaining.
# 79.15665 s (32%) simulated in 1h 37m 28s, estimated 3h 18m 4s remaining.
# 79.30565 s (33%) simulated in 1h 37m 38s, estimated 3h 17m 51s remaining.
# 79.4482 s (33%) simulated in 1h 37m 48s, estimated 3h 17m 40s remaining.
# 79.5953 s (33%) simulated in 1h 37m 58s, estimated 3h 17m 27s remaining.
# 79.7371 s (33%) simulated in 1h 38m 8s, estimated 3h 17m 16s remaining.
# 79.875575 s (33%) simulated in 1h 38m 18s, estimated 3h 17m 5s remaining.
# 80.01435 s (33%) simulated in 1h 38m 28s, estimated 3h 16m 54s remaining.
# 80.161625 s (33%) simulated in 1h 38m 38s, estimated 3h 16m 42s remaining.
# 80.304125 s (33%) simulated in 1h 38m 48s, estimated 3h 16m 30s remaining.
# 80.4453 s (33%) simulated in 1h 38m 58s, estimated 3h 16m 19s remaining.
# 80.583075 s (33%) simulated in 1h 39m 8s, estimated 3h 16m 8s remaining.
# 80.72745 s (33%) simulated in 1h 39m 18s, estimated 3h 15m 56s remaining.
# 80.870525 s (33%) simulated in 1h 39m 28s, estimated 3h 15m 45s remaining.
# 81.0133 s (33%) simulated in 1h 39m 38s, estimated 3h 15m 33s remaining.
# 81.1516 s (33%) simulated in 1h 39m 48s, estimated 3h 15m 23s remaining.
# 81.293375 s (33%) simulated in 1h 39m 58s, estimated 3h 15m 11s remaining.
# 81.4394 s (33%) simulated in 1h 40m 8s, estimated 3h 14m 59s remaining.
# 81.57825 s (33%) simulated in 1h 40m 18s, estimated 3h 14m 48s remaining.
# 81.7115 s (34%) simulated in 1h 40m 28s, estimated 3h 14m 39s remaining.
# 81.847175 s (34%) simulated in 1h 40m 38s, estimated 3h 14m 29s remaining.
# 81.98735 s (34%) simulated in 1h 40m 48s, estimated 3h 14m 18s remaining.
# 82.133725 s (34%) simulated in 1h 40m 58s, estimated 3h 14m 5s remaining.
# 82.270875 s (34%) simulated in 1h 41m 8s, estimated 3h 13m 55s remaining.
# 82.424275 s (34%) simulated in 1h 41m 18s, estimated 3h 13m 41s remaining.
# 82.578975 s (34%) simulated in 1h 41m 28s, estimated 3h 13m 27s remaining.
# 82.73125 s (34%) simulated in 1h 41m 38s, estimated 3h 13m 13s remaining.
# 82.8854 s (34%) simulated in 1h 41m 48s, estimated 3h 13m 0s remaining.
# 83.0401 s (34%) simulated in 1h 41m 58s, estimated 3h 12m 45s remaining.
# 83.1961 s (34%) simulated in 1h 42m 8s, estimated 3h 12m 31s remaining.
# 83.351225 s (34%) simulated in 1h 42m 18s, estimated 3h 12m 17s remaining.
# 83.504675 s (34%) simulated in 1h 42m 28s, estimated 3h 12m 3s remaining.
# 83.65435 s (34%) simulated in 1h 42m 38s, estimated 3h 11m 50s remaining.
# 83.807925 s (34%) simulated in 1h 42m 48s, estimated 3h 11m 37s remaining.
# 83.9627 s (34%) simulated in 1h 42m 58s, estimated 3h 11m 23s remaining.
# 84.117175 s (35%) simulated in 1h 43m 8s, estimated 3h 11m 9s remaining.
# 84.27275 s (35%) simulated in 1h 43m 18s, estimated 3h 10m 55s remaining.
# 84.428475 s (35%) simulated in 1h 43m 28s, estimated 3h 10m 41s remaining.
# 84.583925 s (35%) simulated in 1h 43m 38s, estimated 3h 10m 26s remaining.
# 84.7391 s (35%) simulated in 1h 43m 48s, estimated 3h 10m 12s remaining.
# 84.895625 s (35%) simulated in 1h 43m 58s, estimated 3h 9m 58s remaining.
# 85.052075 s (35%) simulated in 1h 44m 8s, estimated 3h 9m 44s remaining.
# 85.205925 s (35%) simulated in 1h 44m 18s, estimated 3h 9m 30s remaining.
# 85.3389 s (35%) simulated in 1h 44m 28s, estimated 3h 9m 21s remaining.
# 85.491775 s (35%) simulated in 1h 44m 38s, estimated 3h 9m 8s remaining.
# 85.646675 s (35%) simulated in 1h 44m 48s, estimated 3h 8m 54s remaining.
# 85.8016 s (35%) simulated in 1h 44m 58s, estimated 3h 8m 40s remaining.
# 85.956325 s (35%) simulated in 1h 45m 8s, estimated 3h 8m 26s remaining.
# 86.111025 s (35%) simulated in 1h 45m 18s, estimated 3h 8m 12s remaining.
# 86.263025 s (35%) simulated in 1h 45m 28s, estimated 3h 7m 59s remaining.
# 86.403 s (36%) simulated in 1h 45m 38s, estimated 3h 7m 48s remaining.
# 86.558325 s (36%) simulated in 1h 45m 48s, estimated 3h 7m 34s remaining.
# 86.715675 s (36%) simulated in 1h 45m 58s, estimated 3h 7m 20s remaining.
# 86.87285 s (36%) simulated in 1h 46m 8s, estimated 3h 7m 6s remaining.
# 87.030725 s (36%) simulated in 1h 46m 18s, estimated 3h 6m 52s remaining.
# 87.18805 s (36%) simulated in 1h 46m 28s, estimated 3h 6m 37s remaining.
# 87.345775 s (36%) simulated in 1h 46m 38s, estimated 3h 6m 23s remaining.
# 87.503325 s (36%) simulated in 1h 46m 48s, estimated 3h 6m 9s remaining.
# 87.661475 s (36%) simulated in 1h 46m 58s, estimated 3h 5m 55s remaining.
# 87.814025 s (36%) simulated in 1h 47m 8s, estimated 3h 5m 41s remaining.
# 87.970825 s (36%) simulated in 1h 47m 18s, estimated 3h 5m 27s remaining.
# 88.128375 s (36%) simulated in 1h 47m 28s, estimated 3h 5m 13s remaining.
# 88.284475 s (36%) simulated in 1h 47m 38s, estimated 3h 4m 59s remaining.
# 88.4421 s (36%) simulated in 1h 47m 48s, estimated 3h 4m 45s remaining.
# 88.599925 s (36%) simulated in 1h 47m 58s, estimated 3h 4m 31s remaining.
# 88.75775 s (36%) simulated in 1h 48m 8s, estimated 3h 4m 17s remaining.
# 88.916475 s (37%) simulated in 1h 48m 18s, estimated 3h 4m 2s remaining.
# 89.074625 s (37%) simulated in 1h 48m 28s, estimated 3h 3m 48s remaining.
# 89.231975 s (37%) simulated in 1h 48m 38s, estimated 3h 3m 34s remaining.
# 89.38915 s (37%) simulated in 1h 48m 48s, estimated 3h 3m 20s remaining.
# 89.546925 s (37%) simulated in 1h 48m 58s, estimated 3h 3m 6s remaining.
# 89.704575 s (37%) simulated in 1h 49m 8s, estimated 3h 2m 52s remaining.
# 89.862475 s (37%) simulated in 1h 49m 18s, estimated 3h 2m 38s remaining.
# 90.01925 s (37%) simulated in 1h 49m 28s, estimated 3h 2m 24s remaining.
# 90.174625 s (37%) simulated in 1h 49m 38s, estimated 3h 2m 11s remaining.
# 90.331575 s (37%) simulated in 1h 49m 48s, estimated 3h 1m 57s remaining.
# 90.4902 s (37%) simulated in 1h 49m 58s, estimated 3h 1m 43s remaining.
# 90.64805 s (37%) simulated in 1h 50m 8s, estimated 3h 1m 29s remaining.
# 90.80615 s (37%) simulated in 1h 50m 18s, estimated 3h 1m 15s remaining.
# 90.96335 s (37%) simulated in 1h 50m 28s, estimated 3h 1m 1s remaining.
# 91.116975 s (37%) simulated in 1h 50m 38s, estimated 3h 0m 48s remaining.
# 91.275 s (38%) simulated in 1h 50m 48s, estimated 3h 0m 34s remaining.
# 91.43235 s (38%) simulated in 1h 50m 58s, estimated 3h 0m 20s remaining.
# 91.589975 s (38%) simulated in 1h 51m 8s, estimated 3h 0m 6s remaining.
# 91.7482 s (38%) simulated in 1h 51m 18s, estimated 2h 59m 52s remaining.
# 91.905525 s (38%) simulated in 1h 51m 28s, estimated 2h 59m 38s remaining.
# 92.062075 s (38%) simulated in 1h 51m 38s, estimated 2h 59m 25s remaining.
# 92.220775 s (38%) simulated in 1h 51m 48s, estimated 2h 59m 11s remaining.
# 92.379325 s (38%) simulated in 1h 51m 58s, estimated 2h 58m 57s remaining.
# 92.536675 s (38%) simulated in 1h 52m 8s, estimated 2h 58m 43s remaining.
# 92.6942 s (38%) simulated in 1h 52m 18s, estimated 2h 58m 29s remaining.
# 92.8521 s (38%) simulated in 1h 52m 28s, estimated 2h 58m 15s remaining.
# 93.0084 s (38%) simulated in 1h 52m 38s, estimated 2h 58m 2s remaining.
# 93.165225 s (38%) simulated in 1h 52m 48s, estimated 2h 57m 48s remaining.
# 93.32245 s (38%) simulated in 1h 52m 58s, estimated 2h 57m 34s remaining.
# 93.4796 s (38%) simulated in 1h 53m 8s, estimated 2h 57m 21s remaining.
# 93.637175 s (39%) simulated in 1h 53m 18s, estimated 2h 57m 7s remaining.
# 93.794675 s (39%) simulated in 1h 53m 28s, estimated 2h 56m 53s remaining.
# 93.9516 s (39%) simulated in 1h 53m 38s, estimated 2h 56m 40s remaining.
# 94.108125 s (39%) simulated in 1h 53m 48s, estimated 2h 56m 26s remaining.
# 94.2657 s (39%) simulated in 1h 53m 58s, estimated 2h 56m 13s remaining.
# 94.422875 s (39%) simulated in 1h 54m 8s, estimated 2h 55m 59s remaining.
# 94.579725 s (39%) simulated in 1h 54m 18s, estimated 2h 55m 46s remaining.
# 94.737525 s (39%) simulated in 1h 54m 28s, estimated 2h 55m 32s remaining.
# 94.894725 s (39%) simulated in 1h 54m 38s, estimated 2h 55m 19s remaining.
# 95.053775 s (39%) simulated in 1h 54m 48s, estimated 2h 55m 5s remaining.
# 95.211675 s (39%) simulated in 1h 54m 58s, estimated 2h 54m 51s remaining.
# 95.369975 s (39%) simulated in 1h 55m 8s, estimated 2h 54m 37s remaining.
# 95.528025 s (39%) simulated in 1h 55m 18s, estimated 2h 54m 24s remaining.
# 95.6858 s (39%) simulated in 1h 55m 28s, estimated 2h 54m 10s remaining.
# 95.80975 s (39%) simulated in 1h 55m 38s, estimated 2h 54m 3s remaining.
# 95.94855 s (39%) simulated in 1h 55m 48s, estimated 2h 53m 53s remaining.
# 96.10615 s (40%) simulated in 1h 55m 58s, estimated 2h 53m 39s remaining.
# 96.264 s (40%) simulated in 1h 56m 8s, estimated 2h 53m 25s remaining.
# 96.421 s (40%) simulated in 1h 56m 18s, estimated 2h 53m 12s remaining.
# 96.576325 s (40%) simulated in 1h 56m 28s, estimated 2h 52m 59s remaining.
# 96.73 s (40%) simulated in 1h 56m 38s, estimated 2h 52m 46s remaining.
# 96.88425 s (40%) simulated in 1h 56m 48s, estimated 2h 52m 33s remaining.
# 97.0335 s (40%) simulated in 1h 56m 58s, estimated 2h 52m 21s remaining.
# 97.206125 s (40%) simulated in 1h 57m 8s, estimated 2h 52m 5s remaining.
# 97.363675 s (40%) simulated in 1h 57m 18s, estimated 2h 51m 52s remaining.
# 97.519675 s (40%) simulated in 1h 57m 28s, estimated 2h 51m 39s remaining.
# 97.550425 s (40%) simulated in 2h 3m 20s, estimated 3h 0m 7s remaining.
# 97.65465 s (40%) simulated in 2h 3m 30s, estimated 3h 0m 2s remaining.
# 97.79835 s (40%) simulated in 2h 3m 40s, estimated 2h 59m 49s remaining.
# 97.93045 s (40%) simulated in 2h 3m 50s, estimated 2h 59m 39s remaining.
# 98.068225 s (40%) simulated in 2h 4m 0s, estimated 2h 59m 28s remaining.
# 98.21475 s (40%) simulated in 2h 4m 10s, estimated 2h 59m 16s remaining.
# 98.36485 s (40%) simulated in 2h 4m 20s, estimated 2h 59m 2s remaining.
# 98.5194 s (41%) simulated in 2h 4m 30s, estimated 2h 58m 48s remaining.
# 98.675725 s (41%) simulated in 2h 4m 40s, estimated 2h 58m 33s remaining.
# 98.833825 s (41%) simulated in 2h 4m 50s, estimated 2h 58m 19s remaining.
# 98.990875 s (41%) simulated in 2h 5m 0s, estimated 2h 58m 4s remaining.
# 99.14645 s (41%) simulated in 2h 5m 10s, estimated 2h 57m 50s remaining.
# 99.30255 s (41%) simulated in 2h 5m 20s, estimated 2h 57m 35s remaining.
# 99.45945 s (41%) simulated in 2h 5m 30s, estimated 2h 57m 21s remaining.
# 99.61585 s (41%) simulated in 2h 5m 40s, estimated 2h 57m 6s remaining.
# 99.772775 s (41%) simulated in 2h 5m 50s, estimated 2h 56m 52s remaining.
# 99.930925 s (41%) simulated in 2h 6m 0s, estimated 2h 56m 37s remaining.
# 100.088425 s (41%) simulated in 2h 6m 10s, estimated 2h 56m 23s remaining.
# 100.245575 s (41%) simulated in 2h 6m 20s, estimated 2h 56m 8s remaining.
# 100.404 s (41%) simulated in 2h 6m 30s, estimated 2h 55m 53s remaining.
# 100.56085 s (41%) simulated in 2h 6m 40s, estimated 2h 55m 39s remaining.
# 100.69315 s (41%) simulated in 2h 6m 50s, estimated 2h 55m 29s remaining.
# 100.816275 s (42%) simulated in 2h 7m 0s, estimated 2h 55m 20s remaining.
# 100.9611 s (42%) simulated in 2h 7m 10s, estimated 2h 55m 8s remaining.
# 101.09725 s (42%) simulated in 2h 7m 20s, estimated 2h 54m 58s remaining.
# 101.226625 s (42%) simulated in 2h 7m 30s, estimated 2h 54m 48s remaining.
# 101.360425 s (42%) simulated in 2h 7m 40s, estimated 2h 54m 38s remaining.
# 101.492925 s (42%) simulated in 2h 7m 50s, estimated 2h 54m 28s remaining.
# 101.633775 s (42%) simulated in 2h 8m 0s, estimated 2h 54m 16s remaining.
# 101.775625 s (42%) simulated in 2h 8m 10s, estimated 2h 54m 5s remaining.
# 101.9173 s (42%) simulated in 2h 8m 20s, estimated 2h 53m 53s remaining.
# 102.05275 s (42%) simulated in 2h 8m 30s, estimated 2h 53m 42s remaining.
# 102.1802 s (42%) simulated in 2h 8m 40s, estimated 2h 53m 33s remaining.
# 102.32535 s (42%) simulated in 2h 8m 50s, estimated 2h 53m 21s remaining.
# 102.476725 s (42%) simulated in 2h 9m 0s, estimated 2h 53m 8s remaining.
# 102.6238 s (42%) simulated in 2h 9m 10s, estimated 2h 52m 55s remaining.
# 102.77615 s (42%) simulated in 2h 9m 20s, estimated 2h 52m 42s remaining.
# 102.9205 s (42%) simulated in 2h 9m 30s, estimated 2h 52m 29s remaining.
# 103.071425 s (42%) simulated in 2h 9m 40s, estimated 2h 52m 16s remaining.
# 103.219675 s (43%) simulated in 2h 9m 50s, estimated 2h 52m 3s remaining.
# 103.3599 s (43%) simulated in 2h 10m 0s, estimated 2h 51m 52s remaining.
# 103.497025 s (43%) simulated in 2h 10m 10s, estimated 2h 51m 41s remaining.
# 103.628825 s (43%) simulated in 2h 10m 20s, estimated 2h 51m 31s remaining.
# 103.7743 s (43%) simulated in 2h 10m 30s, estimated 2h 51m 19s remaining.
# 103.924375 s (43%) simulated in 2h 10m 40s, estimated 2h 51m 6s remaining.
# 104.078625 s (43%) simulated in 2h 10m 50s, estimated 2h 50m 52s remaining.
# 104.226825 s (43%) simulated in 2h 11m 0s, estimated 2h 50m 40s remaining.
# 104.37865 s (43%) simulated in 2h 11m 10s, estimated 2h 50m 26s remaining.
# 104.534975 s (43%) simulated in 2h 11m 20s, estimated 2h 50m 12s remaining.
# 104.692325 s (43%) simulated in 2h 11m 30s, estimated 2h 49m 58s remaining.
# 104.84785 s (43%) simulated in 2h 11m 40s, estimated 2h 49m 44s remaining.
# 104.975225 s (43%) simulated in 2h 11m 50s, estimated 2h 49m 35s remaining.
# 105.132375 s (43%) simulated in 2h 12m 0s, estimated 2h 49m 21s remaining.
# 105.2877 s (43%) simulated in 2h 12m 10s, estimated 2h 49m 7s remaining.
# 105.44145 s (43%) simulated in 2h 12m 20s, estimated 2h 48m 53s remaining.
# 105.5988 s (43%) simulated in 2h 12m 30s, estimated 2h 48m 39s remaining.
# 105.7542 s (44%) simulated in 2h 12m 40s, estimated 2h 48m 25s remaining.
# 105.911975 s (44%) simulated in 2h 12m 50s, estimated 2h 48m 11s remaining.
# 106.0691 s (44%) simulated in 2h 13m 0s, estimated 2h 47m 57s remaining.
# 106.2272 s (44%) simulated in 2h 13m 10s, estimated 2h 47m 42s remaining.
# 106.3842 s (44%) simulated in 2h 13m 20s, estimated 2h 47m 28s remaining.
# 106.541675 s (44%) simulated in 2h 13m 30s, estimated 2h 47m 14s remaining.
# 106.6994 s (44%) simulated in 2h 13m 40s, estimated 2h 47m 0s remaining.
# 106.858075 s (44%) simulated in 2h 13m 50s, estimated 2h 46m 46s remaining.
# 107.01575 s (44%) simulated in 2h 14m 0s, estimated 2h 46m 32s remaining.
# 107.1737 s (44%) simulated in 2h 14m 10s, estimated 2h 46m 17s remaining.
# 107.330725 s (44%) simulated in 2h 14m 20s, estimated 2h 46m 3s remaining.
# 107.4871 s (44%) simulated in 2h 14m 30s, estimated 2h 45m 49s remaining.
# 107.643875 s (44%) simulated in 2h 14m 40s, estimated 2h 45m 36s remaining.
# 107.792725 s (44%) simulated in 2h 14m 50s, estimated 2h 45m 23s remaining.
# 107.928175 s (44%) simulated in 2h 15m 0s, estimated 2h 45m 13s remaining.
# 108.055575 s (45%) simulated in 2h 15m 10s, estimated 2h 45m 4s remaining.
# 108.15955 s (45%) simulated in 2h 15m 20s, estimated 2h 44m 58s remaining.
# 108.265475 s (45%) simulated in 2h 15m 30s, estimated 2h 44m 53s remaining.
# 108.36775 s (45%) simulated in 2h 15m 40s, estimated 2h 44m 48s remaining.
# 108.461275 s (45%) simulated in 2h 15m 50s, estimated 2h 44m 45s remaining.
# 108.56805 s (45%) simulated in 2h 16m 0s, estimated 2h 44m 39s remaining.
# 108.680775 s (45%) simulated in 2h 16m 10s, estimated 2h 44m 32s remaining.

# %%
# %%time
from read_data import *
Create_output("_Learned_BCM",width,Noise_statemon,Noise_extended_statemon,PC_Statemon,PC_Spikemon, PC_rate,DCN_Statemon,DCN_Spikemon, DCN_rate,IO_Statemon,IO_Spikemon,IO_rate,mon_N_PC,Noise_statemon_Coupled,Noise_extended_statemon_Coupled,PC_Statemon_Coupled,PC_Spikemon_Coupled, PC_rate_Coupled,DCN_Statemon_Coupled,DCN_Spikemon_Coupled,DCN_rate_Coupled,IO_Statemon_Coupled,IO_Spikemon_Coupled,IO_rate_Coupled,mon_N_PC_Coupled)

# %%
for ii in range(0,Params.N_Noise):
    plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
    plot(Noise_extended_statemon.t/ms,Input_presyn_statemon.rho_presyn[ii],label="delta_weight dendrite "+str(ii+1))
    ylabel('V [mV]')
    xlabel('Time [ms]')
    legend()
    show()

# %%
width = 500*ms
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
plot(IO_rate.t, IO_rate.smooth_rate(window='gaussian', width=width)/Hz, label='IO_Uncoupled')
plot(IO_rate_Coupled.t, IO_rate_Coupled.smooth_rate(window='gaussian', width=width)/Hz, label='IO_Coupled')
title('Population rate monitor for '+str(N_Cells_IO)+" cells")
ylabel('Rate [Hz]')
xlabel('Time [ms]')
legend()
show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
plot(PC_rate.t, PC_rate.smooth_rate(window='gaussian', width=width)/Hz, label='PC_Uncoupled')
plot(PC_rate_Coupled.t, PC_rate_Coupled.smooth_rate(window='gaussian', width=width)/Hz, label='PC_Coupled')
title('Population rate monitor for '+str(N_Cells_IO)+" cells")
ylabel('Rate [Hz]')
xlabel('Time [ms]')
legend()
show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
plot(DCN_rate.t, DCN_rate.smooth_rate(window='gaussian', width=width)/Hz, label='DCN_Uncoupled')
plot(DCN_rate_Coupled.t, DCN_rate_Coupled.smooth_rate(window='gaussian', width=width)/Hz, label='DCN_Coupled')
title('Population rate monitor for '+str(N_Cells_IO)+" cells")
ylabel('Rate [Hz]')
xlabel('Time [ms]')
legend()
show()

# %%
# %%time
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,N_Cells_PC):
    vm = PC_Statemon[ii].v[:]
    for t in PC_Spikemon.t:
        i = int(t / dt_rec)
        vm[i] = 20*mV
    plot(PC_Statemon.t/ms,vm/mV, label='PC_'+str(ii+1))
title('Membrane Potential for '+str(N_Cells_PC)+" PC cells (Uncoupled)")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,N_Cells_IO):
    plot(IO_Statemon.t/ms,IO_Statemon.Vs[ii]/mV, label='IO_'+str(ii+1))
title('Membrane Potential for '+str(N_Cells_IO)+" IO cells (Uncoupled)")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,N_Cells_PC):
    vm_Coupled = PC_Statemon_Coupled[ii].v[:]
    for t in PC_Spikemon_Coupled.t:
        i = int(t / dt_rec)
        vm_Coupled[i] = 20*mV
    plot(PC_Statemon_Coupled.t/ms,vm_Coupled/mV, label='PC_'+str(ii+1))
title('Membrane Potential for '+str(N_Cells_PC)+" PC cells (Coupled)")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,N_Cells_IO):
    plot(IO_Statemon_Coupled.t/ms,IO_Statemon_Coupled.Vs[ii]/mV, label='IO_'+str(ii+1))
title('Membrane Potential for '+str(N_Cells_IO)+" cells (Coupled)")
ylabel('V [mV]')
xlabel('Time [ms]')
legend()
show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC*Params.N_Noise):
    plot(mon_N_PC.rho_PC[0],mon_N_PC.phi[ii])
ylabel('phi [Hz]')
xlabel('rho_PC [Hz]')
show()

plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC*Params.N_Noise):
    plot(mon_N_PC.t/ms,mon_N_PC.thresh_M[ii])
ylabel('thresh_M [Hz]')
xlabel('Time [ms]')
show()

# %%
plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')
for ii in range(0,Params.N_Cells_PC*Params.N_Noise):
    plot(mon_N_PC.t/ms,mon_N_PC.thresh_M[ii],label=str(ii))
ylabel('thresh_M [Hz]')
xlabel('Time [ms]')
legend()
show()
